# %% [markdown]
# ## Section 1 — Centralized Configuration
#
# This is the **single source of truth** for every tunable parameter.
# All downstream cells read exclusively from the  namespace.
# To switch models or adjust hyperparameters, only edit this cell.

# %%
import shutil
import os

SRC = "/kaggle/input/datasets/swiri212/gru-model/BiGRU"
DST = "/kaggle/working/BiGRU"

# امسح القديم لو موجود (عشان نتأكد 100%)
if os.path.exists(DST):
    shutil.rmtree(DST)

# %%
import shutil
import os

SRC = "/kaggle/input/datasets/swiri212/bigru-final/BiGRU"
DST = "/kaggle/working/BiGRU"

# امسح القديم لو موجود (عشان نتأكد 100%)
if os.path.exists(DST):
    shutil.rmtree(DST)

# انسخ من input → working
shutil.copytree(SRC, DST)

print("Checkpoint restored successfully.")
# Out:
# Checkpoint restored successfully.

# %%
import os

class CFG:
    # ── Model identity ────────────────────────────────────────────────────────
    MODEL_NAME       = "BiGRU"       # Switch between models by changing this value

    # ── Training hyperparameters ──────────────────────────────────────────────
    EPOCHS           = 100
    BATCH_SIZE       = 128
    LEARNING_RATE    = 1e-3
    MIN_LR           = 1e-6
    WARMUP_RATIO     = 0.05           # Fraction of total steps used for LR warm-up
    WEIGHT_DECAY     = 1e-4
    LABEL_SMOOTHING  = 0.1
    EARLY_STOP_PAT   = 20             # Early-stopping patience in epochs

    # ── Gradient accumulation ─────────────────────────────────────────────────
    GRAD_ACCUM_STEPS = 1              # Set > 1 to simulate a larger effective batch

    # ── Precision ─────────────────────────────────────────────────────────────
    USE_AMP          = True           # Enable mixed-precision (FP16) training
   
    RESET_CHECKPOINT = False   # اضبطه True لما تغير الـ architecture
                              # ارجعه False بعد أول run ناجح

    # ── Reproducibility ───────────────────────────────────────────────────────
    SEED             = 42

    # ── Data dimensions (must match the Preprocess layer) ────────────────────
    ROWS_PER_FRAME   = 543
    MAX_LEN          = 384
    NUM_CLASSES      = 250
    PAD_VALUE        = -100.0

    # ── Dataset paths ─────────────────────────────────────────────────────────
    DATA_DIR         = "/kaggle/input/competitions/asl-signs"
    TRAIN_CSV        = os.path.join(DATA_DIR, "train.csv")
    LANDMARK_DIR     = os.path.join(DATA_DIR, "train_landmark_files")
    SIGN_MAP         = os.path.join(DATA_DIR, "sign_to_prediction_index_map.json")

    # ── Output root ───────────────────────────────────────────────────────────
    WORKING_DIR      = "/kaggle/working"

    # ── Logging flags ─────────────────────────────────────────────────────────
    USE_LOGGING      = True           # Write structured logs to file
    LOG_LEVEL        = "INFO"        # DEBUG | INFO | WARNING | ERROR

    # ── Comparison summary ────────────────────────────────────────────────────
    COMPARISON_CSV   = os.path.join(WORKING_DIR, "model_comparison_summary.csv")

# %% [markdown]
# ## Section 2 — Library Imports
#
# All third-party dependencies are imported in one place.
# No data pipeline code is modified by this cell.

# %%
# Standard library
import sys
import gc
import time
import math
import random
import logging
import datetime
import traceback
import json
from pathlib import Path

# Data and visualisation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.autonotebook import tqdm

# Machine learning
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, classification_report

# Deep learning
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers, metrics, losses, optimizers, mixed_precision
from tensorflow.keras.utils import plot_model
# Out:
# /tmp/ipykernel_22/3676585380.py:18: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# 2026-04-13 11:34:45.972830: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776080086.193830      22 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776080086.257211      22 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776080086.764822      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776080086.764864      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776080086.764868      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776080086.764870      22 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %% [markdown]
# ## Section 3 — Logging System
#
# A structured, dual-output logger writes to both a dedicated per-experiment
# log file and to stdout. This replaces all bare  statements in
# training and evaluation code.

# %%
def setup_logger(model_name, log_dir, level="INFO"):
    os.makedirs(log_dir, exist_ok=True)
    timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
    log_file  = os.path.join(log_dir, f"{model_name}_{timestamp}.log")

    logger = logging.getLogger(model_name)
    logger.setLevel(getattr(logging, level.upper(), logging.INFO))
    logger.handlers.clear()

    fmt = logging.Formatter(
        "[%(asctime)s] [%(name)s] [%(levelname)s]  %(message)s",
        datefmt="%Y-%m-%d %H:%M:%S",
    )
    fh = logging.FileHandler(log_file, encoding="utf-8")
    fh.setFormatter(fmt)
    logger.addHandler(fh)

    sh = logging.StreamHandler(sys.stdout)
    sh.setFormatter(fmt)
    logger.addHandler(sh)

    logger.propagate = False
    logger.info("Logger initialised — writing to: %s", log_file)
    return logger

logger = logging.getLogger("pipeline")
logging.basicConfig(level=logging.INFO)
logger.info("Temporary root logger active until output directories are ready.")
# Out:
# INFO:pipeline:Temporary root logger active until output directories are ready.

# %% [markdown]
# ## Section 4 — Reproducibility
#
# Fixed random seeds are applied to Python, NumPy, and TensorFlow.
# Deterministic op mode is enabled so that identical runs yield identical results.

# %%
os.environ["PYTHONHASHSEED"]      = str(CFG.SEED)
os.environ["TF_DETERMINISTIC_OPS"] = "1"

random.seed(CFG.SEED)
np.random.seed(CFG.SEED)
tf.random.set_seed(CFG.SEED)

logger.info("Global seed set to %d. Deterministic ops enabled.", CFG.SEED)
# Out:
# INFO:pipeline:Global seed set to 42. Deterministic ops enabled.

# %% [markdown]
# ## Section 5 — Device Detection and Mixed Precision
#
# GPUs are detected and memory growth is enabled to avoid OOM errors.
# AMP (FP16) is activated when  and a GPU is available,
# halving memory usage and increasing throughput with no code changes elsewhere.

# %%
gpus = tf.config.list_physical_devices("GPU")
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

if gpus:
    logger.info("GPU(s) detected: %s", [g.name for g in gpus])
else:
    logger.warning("No GPU detected — training will run on CPU.")

if CFG.USE_AMP and gpus:
    mixed_precision.set_global_policy("mixed_float16")
    logger.info("Mixed precision policy: mixed_float16")
else:
    mixed_precision.set_global_policy("float32")
    logger.info("Mixed precision disabled — using float32.")

logger.info("TensorFlow  : %s", tf.__version__)
logger.info("Python      : %s", sys.version.split()[0])
logger.info("NumPy       : %s", np.__version__)
logger.info("Pandas      : %s", pd.__version__)
logger.info("Scikit-Learn: %s", sklearn.__version__)
# Out:
# INFO:pipeline:GPU(s) detected: ['/physical_device:GPU:0', '/physical_device:GPU:1']
# INFO:pipeline:Mixed precision policy: mixed_float16
# INFO:pipeline:TensorFlow  : 2.19.0
# INFO:pipeline:Python      : 3.12.12
# INFO:pipeline:NumPy       : 2.0.2
# INFO:pipeline:Pandas      : 2.3.3
# INFO:pipeline:Scikit-Learn: 1.6.1

# %% [markdown]
# ## Section 6 — Output Directory Structure
#
# A standardised directory tree is created for every model:

# %%
def build_output_dirs(working_dir, model_name):
    base = os.path.join(working_dir, model_name)
    dirs = {
        "base":        base,
        "checkpoints": os.path.join(base, "checkpoints"),
        "logs":        os.path.join(base, "logs"),
        "metrics":     os.path.join(base, "metrics"),
        "predictions": os.path.join(base, "predictions"),
        "plots":       os.path.join(base, "plots"),
    }
    for path in dirs.values():
        os.makedirs(path, exist_ok=True)
    return dirs

DIRS = build_output_dirs(CFG.WORKING_DIR, CFG.MODEL_NAME)

logger = setup_logger(CFG.MODEL_NAME, DIRS["logs"], CFG.LOG_LEVEL)
logger.info("Output directories ready: %s", DIRS["base"])
# Out:
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Logger initialised — writing to: /kaggle/working/BiGRU/logs/BiGRU_20260413_113512.log
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Output directories ready: /kaggle/working/BiGRU

# %% [markdown]
# ## Section 7 — Data Paths
#
# Input paths are derived from  and verified.
# **This cell is part of the protected data pipeline and must not be modified.**

# %%
DATA_DIR     = Path(CFG.DATA_DIR)
TRAIN_CSV    = Path(CFG.TRAIN_CSV)
LANDMARK_DIR = Path(CFG.LANDMARK_DIR)
SIGN_MAP     = Path(CFG.SIGN_MAP)

logger.info("DATA_DIR     : %s  exists=%s", DATA_DIR,     DATA_DIR.exists())
logger.info("TRAIN_CSV    : %s  exists=%s", TRAIN_CSV,    TRAIN_CSV.exists())
logger.info("LANDMARK_DIR : %s  exists=%s", LANDMARK_DIR, LANDMARK_DIR.exists())

parquet_folders = list(LANDMARK_DIR.glob("*")) if LANDMARK_DIR.exists() else []
logger.info("Parquet participant folders found: %d", len(parquet_folders))
# Out:
# [2026-04-13 11:35:12] [BiGRU] [INFO]  DATA_DIR     : /kaggle/input/competitions/asl-signs  exists=True
# [2026-04-13 11:35:12] [BiGRU] [INFO]  TRAIN_CSV    : /kaggle/input/competitions/asl-signs/train.csv  exists=True
# [2026-04-13 11:35:12] [BiGRU] [INFO]  LANDMARK_DIR : /kaggle/input/competitions/asl-signs/train_landmark_files  exists=True
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Parquet participant folders found: 21

# %% [markdown]
# ## Section 8 — Raw Data Loading
#
# The training manifest CSV is loaded and its shape is logged.
# **This cell is part of the protected data pipeline and must not be modified.**

# %%
train_df = pd.read_csv(TRAIN_CSV)
display(train_df.head())
display(train_df.info())

logger.info("train.csv: %d rows | %d unique signs | %d participants",
            len(train_df), train_df["sign"].nunique(), train_df["participant_id"].nunique())
# Out:
#                                             path  participant_id  sequence_id  \
# 0  train_landmark_files/26734/1000035562.parquet           26734   1000035562
# 1  train_landmark_files/28656/1000106739.parquet           28656   1000106739
# 2   train_landmark_files/16069/100015657.parquet           16069    100015657
# 3  train_landmark_files/25571/1000210073.parquet           25571   1000210073
# 4  train_landmark_files/62590/1000240708.parquet           62590   1000240708
#
#     sign
# 0   blow
# 1   wait
# 2  cloud
# 3   bird
# 4   owie
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94477 entries, 0 to 94476
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   path            94477 non-null  object
#  1   participant_id  94477 non-null  int64
#  2   sequence_id     94477 non-null  int64
#  3   sign            94477 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 2.9+ MB
# None
# [2026-04-13 11:35:12] [BiGRU] [INFO]  train.csv: 94477 rows | 250 unique signs | 21 participants

# %% [markdown]
# ## Section 9 — Spatial-Temporal Feature Engineering
#
# This block defines the core preprocessing pipeline:
#
# 1. **Landmark index sets** — 543 raw MediaPipe nodes are reduced to the most
#    informative subset (lips, eyes, nose, hands), reducing noise and compute.
# 2. **NaN-safe statistics** —  /  handle frames with
#    missing detections without propagating  through the network.
# 3. ** Keras layer** — a differentiable, graph-compatible layer that
#    normalises coordinates, computes velocity (first derivative) and acceleration
#    (second derivative) across frames, and concatenates them into a single feature
#    vector of shape .
#
# **This cell is part of the protected data pipeline and must not be modified.**

# %%
# ── Data constants ────────────────────────────────────────────────────────────
ROWS_PER_FRAME = CFG.ROWS_PER_FRAME
MAX_LEN        = CFG.MAX_LEN
CROP_LEN       = MAX_LEN
NUM_CLASSES    = CFG.NUM_CLASSES
PAD            = CFG.PAD_VALUE

# ── Landmark index definitions ────────────────────────────────────────────────
NOSE  = [1, 2, 98, 327]
LNOSE = [98]
RNOSE = [327]

LIP = [
    0, 61, 185, 40, 39, 37, 267, 269, 270, 409,
    291, 146, 91, 181, 84, 17, 314, 405, 321, 375,
    78, 191, 80, 81, 82, 13, 312, 311, 310, 415,
    95, 88, 178, 87, 14, 317, 402, 318, 324, 308,
]
LLIP = [84, 181, 91, 146, 61, 185, 40, 39, 37, 87, 178, 88, 95, 78, 191, 80, 81, 82]
RLIP = [314, 405, 321, 375, 291, 409, 270, 269, 267, 317, 402, 318, 324, 308, 415, 310, 311, 312]

POSE  = [500, 502, 504, 501, 503, 505, 512, 513]
LPOSE = [513, 505, 503, 501]
RPOSE = [512, 504, 502, 500]

REYE = [33, 7, 163, 144, 145, 153, 154, 155, 133, 246, 161, 160, 159, 158, 157, 173]
LEYE = [263, 249, 390, 373, 374, 380, 381, 382, 362, 466, 388, 387, 386, 385, 384, 398]

LHAND = np.arange(468, 489).tolist()
RHAND = np.arange(522, 543).tolist()

POINT_LANDMARKS = LIP + LHAND + RHAND + NOSE + REYE + LEYE

NUM_NODES = len(POINT_LANDMARKS)
CHANNELS  = 6 * NUM_NODES   # (X, Y) x (position, velocity, acceleration)

logger.info("Selected landmark nodes: %d  |  Feature channels: %d", NUM_NODES, CHANNELS)


# ── NaN-safe statistics ───────────────────────────────────────────────────────
def tf_nan_mean(x, axis=0, keepdims=False):
    sum_val   = tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), x),    axis=axis, keepdims=keepdims)
    count_val = tf.reduce_sum(tf.where(tf.math.is_nan(x), tf.zeros_like(x), tf.ones_like(x)), axis=axis, keepdims=keepdims)
    return sum_val / count_val

def tf_nan_std(x, center=None, axis=0, keepdims=False):
    if center is None:
        center = tf_nan_mean(x, axis=axis, keepdims=True)
    d = x - center
    return tf.math.sqrt(tf_nan_mean(d * d, axis=axis, keepdims=keepdims))


# ── Preprocess Keras layer ────────────────────────────────────────────────────
class Preprocess(tf.keras.layers.Layer):
    def __init__(self, max_len=MAX_LEN, point_landmarks=POINT_LANDMARKS, **kwargs):
        super().__init__(**kwargs)
        self.max_len         = max_len
        self.point_landmarks = point_landmarks

    def call(self, inputs):
        if inputs.shape.rank == 3:
            x = inputs[None, ...]
        else:
            x = inputs

        mean = tf_nan_mean(tf.gather(x, [17], axis=2), axis=[1, 2], keepdims=True)
        mean = tf.where(tf.math.is_nan(mean), tf.constant(0.5, x.dtype), mean)

        x   = tf.gather(x, self.point_landmarks, axis=2)
        std = tf_nan_std(x, center=mean, axis=[1, 2], keepdims=True)
        x   = (x - mean) / std

        if self.max_len is not None:
            x = x[:, :self.max_len]

        length = tf.shape(x)[1]
        x = x[..., :2]

        dx = tf.cond(
            tf.shape(x)[1] > 1,
            lambda: tf.pad(x[:, 1:] - x[:, :-1], [[0,0],[0,1],[0,0],[0,0]]),
            lambda: tf.zeros_like(x),
        )
        dx2 = tf.cond(
            tf.shape(x)[1] > 2,
            lambda: tf.pad(x[:, 2:] - x[:, :-2], [[0,0],[0,2],[0,0],[0,0]]),
            lambda: tf.zeros_like(x),
        )

        x = tf.concat([
            tf.reshape(x,   (-1, length, 2 * len(self.point_landmarks))),
            tf.reshape(dx,  (-1, length, 2 * len(self.point_landmarks))),
            tf.reshape(dx2, (-1, length, 2 * len(self.point_landmarks))),
        ], axis=-1)

        x = tf.where(tf.math.is_nan(x), tf.constant(0., x.dtype), x)
        return x

    def get_config(self):
        config = super().get_config()
        config.update({"max_len": self.max_len, "point_landmarks": self.point_landmarks})
        return config


preprocess_layer = Preprocess(max_len=MAX_LEN, point_landmarks=POINT_LANDMARKS)
logger.info("Preprocess layer instantiated.")
# Out:
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Selected landmark nodes: 118  |  Feature channels: 708
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Preprocess layer instantiated.

# %% [markdown]
# ## Section 10 — Data Augmentation and Parquet Pipeline
#
# Five spatiotemporal augmentations improve generalisation:
#
# | Augmentation | Effect |
# |---|---|
# |  | Mirrors hands and face (left ↔ right signer) |
# |  | Randomly alters signing speed |
# |  | Rotation, scale, and shear transforms |
# |  | Blanks a random contiguous time window |
# |  | Blanks a random spatial region per frame |
#
#  wraps a Python generator in
# and returns a prefetch-optimised pipeline.
#
# **This cell is part of the protected data pipeline and must not be modified.**

# %%
# ── Label encoding ────────────────────────────────────────────────────────────
if "label" not in train_df.columns:
    sign_list     = sorted(train_df["sign"].unique())
    sign_to_label = {sign: label for label, sign in enumerate(sign_list)}
    label_to_sign = {label: sign for sign, label in sign_to_label.items()}
    train_df["label"] = train_df["sign"].map(sign_to_label)
    logger.info("Encoded %d unique sign classes.", len(sign_list))


# ── Parquet reader ─────────────────────────────────────────────────────────────
def load_parquet_video(file_path):
    try:
        df     = pd.read_parquet(file_path, columns=["x", "y", "z"], engine="pyarrow")
        coords = df.values.astype(np.float32)
        frames = len(coords) // ROWS_PER_FRAME
        return coords.reshape(frames, ROWS_PER_FRAME, 3)
    except Exception:
        return np.zeros((0, ROWS_PER_FRAME, 3), dtype=np.float32)


# ── Augmentation helpers ───────────────────────────────────────────────────────
def filter_nans_tf(x, ref_point=POINT_LANDMARKS):
    mask = tf.math.logical_not(
        tf.reduce_all(tf.math.is_nan(tf.gather(x, ref_point, axis=1)), axis=[-2, -1])
    )
    return tf.boolean_mask(x, mask, axis=0)


def flip_lr(x):
    x_coord, y_coord, z_coord = tf.unstack(x, axis=-1)
    x_coord = 1 - x_coord
    new_x   = tf.stack([x_coord, y_coord, z_coord], -1)
    new_x   = tf.transpose(new_x, [1, 0, 2])
    for left, right in [(LHAND, RHAND), (LLIP, RLIP), (LPOSE, RPOSE), (LEYE, REYE), (LNOSE, RNOSE)]:
        lv    = tf.gather(new_x, left,  axis=0)
        rv    = tf.gather(new_x, right, axis=0)
        new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(left) [..., None], rv)
        new_x = tf.tensor_scatter_nd_update(new_x, tf.constant(right)[..., None], lv)
    return tf.transpose(new_x, [1, 0, 2])


def interp1d_(x, target_len, method="random"):
    target_len = tf.maximum(1, target_len)
    width      = tf.shape(x)[1]
    size       = [target_len, width]
    if method == "random":
        rand_val = tf.random.uniform(())
        if rand_val < 0.33:
            x = tf.image.resize(x, size, "bilinear")
        elif rand_val < 0.66:
            x = tf.image.resize(x, size, "bicubic")
        else:
            x = tf.image.resize(x, size, "nearest")
    else:
        x = tf.image.resize(x, size, method)
    return x


def resample(x, rate=(0.8, 1.2)):
    rate     = tf.random.uniform((), rate[0], rate[1])
    length   = tf.shape(x)[0]
    new_size = tf.cast(rate * tf.cast(length, tf.float32), tf.int32)
    return interp1d_(x, new_size)


def spatial_random_affine(xyz, scale=(0.8, 1.2), shear=(-0.15, 0.15), shift=(-0.1, 0.1), degree=(-30, 30)):
    center = tf.constant([0.5, 0.5])
    if scale is not None:
        xyz = tf.random.uniform((), *scale) * xyz
    if shear is not None:
        xy, z   = xyz[..., :2], xyz[..., 2:]
        shear_x = shear_y = tf.random.uniform((), *shear)
        if tf.random.uniform(()) < 0.5:
            shear_x = 0.
        else:
            shear_y = 0.
        shear_mat = tf.identity([[1., shear_x], [shear_y, 1.]])
        xy        = xy @ shear_mat
        center    = center + [shear_y, shear_x]
        xyz       = tf.concat([xy, z], axis=-1)
    if degree is not None:
        xy, z   = xyz[..., :2], xyz[..., 2:]
        xy     -= center
        radian  = tf.random.uniform((), *degree) / 180 * np.pi
        c, s    = tf.math.cos(radian), tf.math.sin(radian)
        rot     = tf.identity([[c, s], [-s, c]])
        xy      = xy @ rot + center
        xyz     = tf.concat([xy, z], axis=-1)
    if shift is not None:
        xyz = xyz + tf.random.uniform((), *shift)
    return xyz


def temporal_crop(x, length=MAX_LEN):
    l      = tf.shape(x)[0]
    offset = tf.random.uniform((), 0, tf.clip_by_value(l - length, 1, length), dtype=tf.int32)
    return x[offset: offset + length]


def temporal_mask(x, size=(0.2, 0.4), mask_value=float("nan")):
    l           = tf.shape(x)[0]
    mask_size   = tf.cast(tf.cast(l, tf.float32) * tf.random.uniform((), *size), tf.int32)
    mask_offset = tf.random.uniform((), 0, tf.clip_by_value(l - mask_size, 1, l), dtype=tf.int32)
    indices     = tf.range(mask_offset, mask_offset + mask_size)[..., None]
    updates     = tf.fill([mask_size, ROWS_PER_FRAME, 3], mask_value)
    return tf.tensor_scatter_nd_update(x, indices, updates)


def spatial_mask(x, size=(0.2, 0.4), mask_value=float("nan")):
    mask_offset_y = tf.random.uniform(())
    mask_offset_x = tf.random.uniform(())
    mask_size     = tf.random.uniform((), *size)
    mask_x        = (mask_offset_x < x[..., 0]) & (x[..., 0] < mask_offset_x + mask_size)
    mask_y        = (mask_offset_y < x[..., 1]) & (x[..., 1] < mask_offset_y + mask_size)
    return tf.where((mask_x & mask_y)[..., None], mask_value, x)


def augment_fn(x, max_len=None):
    if tf.random.uniform(()) < 0.80: x = resample(x, (0.5, 1.5))
    if tf.random.uniform(()) < 0.50: x = flip_lr(x)
    if max_len is not None:           x = temporal_crop(x, max_len)
    if tf.random.uniform(()) < 0.75: x = spatial_random_affine(x)
    if tf.random.uniform(()) < 0.50: x = temporal_mask(x)
    if tf.random.uniform(()) < 0.50: x = spatial_mask(x)
    return x


def process_data(coord, label, augment=False, max_len=MAX_LEN):
    coord     = filter_nans_tf(coord)
    if augment:
        coord = augment_fn(coord, max_len=max_len)
    coord     = tf.ensure_shape(coord, (None, ROWS_PER_FRAME, 3))
    processed = preprocess_layer(coord)
    processed = tf.squeeze(processed, axis=0)
    processed = tf.cast(processed, tf.float32)
    return processed, tf.one_hot(label, NUM_CLASSES)


def get_parquet_dataset(df, data_dir=CFG.DATA_DIR, batch_size=CFG.BATCH_SIZE,
                        max_len=MAX_LEN, augment=False, shuffle=False):
    def generator():
        sample_df = df.sample(frac=1).reset_index(drop=True) if shuffle else df
        for _, row in sample_df.iterrows():
            file_path = os.path.normpath(
                os.path.join(data_dir, str(row["path"]).replace("\\", "/"))
            )
            coords = load_parquet_video(file_path)
            if coords.shape[0] > 0:
                yield coords, int(row["label"])

    ds = tf.data.Dataset.from_generator(
        generator,
        output_signature=(
            tf.TensorSpec(shape=(None, ROWS_PER_FRAME, 3), dtype=tf.float32),
            tf.TensorSpec(shape=(),                        dtype=tf.int32),
        ),
    )
    ds = ds.map(
        lambda x, y: process_data(x, y, augment=augment, max_len=max_len),
        num_parallel_calls=tf.data.AUTOTUNE,
    )
    ds = ds.padded_batch(
        batch_size,
        padding_values=(tf.cast(PAD, tf.float32), tf.cast(0.0, tf.float32)),
        padded_shapes=([max_len, CHANNELS], [NUM_CLASSES]),
        drop_remainder=True,
    )
    ds = ds.repeat()
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds
# Out:
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Encoded 250 unique sign classes.

# %% [markdown]
# ## Section 11 — Pipeline Sanity Check
#
# A small batch is run through the pipeline to verify tensor shapes and dtypes
# before any expensive computation begins.

# %%
logger.info("Running pipeline sanity check on 10 samples...")
_test_ds = get_parquet_dataset(train_df.head(10), batch_size=2, augment=True)
for _bx, _by in _test_ds.take(1):
    logger.info("Sanity check X: %s  Y: %s  dtype: %s", _bx.shape, _by.shape, _bx.dtype)
del _test_ds
gc.collect()
# Out:
# [2026-04-13 11:35:12] [BiGRU] [INFO]  Running pipeline sanity check on 10 samples...
# I0000 00:00:1776080113.318220      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1776080113.324230      22 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 2026-04-13 11:35:14.691280: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_4}}
# [2026-04-13 11:35:15] [BiGRU] [INFO]  Sanity check X: (2, 384, 708)  Y: (2, 250)  dtype: <dtype: 'float32'>
# 5264

# %% [markdown]
# ## Section 12 — Batch Tensor Inspection
#
# One batch is extracted and its statistical properties are logged to confirm
# that normalisation is centred near zero and one-hot encoding is correct.

# %%
_inspect_ds = get_parquet_dataset(train_df.head(10), batch_size=2, augment=False)
for _bx, _by in _inspect_ds.take(1):
    _x = _bx.numpy()
    _y = _by.numpy()
    logger.info("Feature tensor — shape: %s  min: %.4f  max: %.4f  mean: %.4f",
                _x.shape, _x.min(), _x.max(), _x.mean())
    logger.info("Label tensor   — shape: %s  active class: %d  (%s)",
                _y.shape, _y[0].argmax(), label_to_sign.get(int(_y[0].argmax()), "unknown"))
del _inspect_ds
gc.collect()
# Out:
# [2026-04-13 11:35:15] [BiGRU] [INFO]  Feature tensor — shape: (2, 384, 708)  min: -100.0000  max: 4.2930  mean: -95.5772
# [2026-04-13 11:35:15] [BiGRU] [INFO]  Label tensor   — shape: (2, 250)  active class: 25  (blow)
# 1712

# %% [markdown]
# ## Section 13 — Stratified Train / Validation / Test Split
#
# The dataset is split 80% / 10% / 10% with stratification on the class label
# to ensure consistent class frequencies across all three sets.  Splits are
# written to disk so that every model in the comparison trains and evaluates on
# exactly the same partitions.
#
# **This cell is part of the protected data pipeline and must not be modified.**

# %%
logger.info("Performing stratified 80/10/10 split  seed=%d.", CFG.SEED)

_data_dir = os.path.join(DIRS["base"], "data")
os.makedirs(_data_dir, exist_ok=True)

train_df_split, temp_df = train_test_split(
    train_df, test_size=0.20, random_state=CFG.SEED, stratify=train_df["label"]
)
val_df_split, test_df_split = train_test_split(
    temp_df, test_size=0.50, random_state=CFG.SEED, stratify=temp_df["label"]
)

train_df_split.to_csv(os.path.join(_data_dir, "train_split.csv"), index=False)
val_df_split  .to_csv(os.path.join(_data_dir, "val_split.csv"),   index=False)
test_df_split .to_csv(os.path.join(_data_dir, "test_split.csv"),  index=False)

logger.info("Training   : %d samples  (%.1f%%)", len(train_df_split), 100*len(train_df_split)/len(train_df))
logger.info("Validation : %d samples  (%.1f%%)", len(val_df_split),   100*len(val_df_split)/len(train_df))
logger.info("Test       : %d samples  (%.1f%%)", len(test_df_split),  100*len(test_df_split)/len(train_df))
# Out:
# [2026-04-13 11:35:15] [BiGRU] [INFO]  Performing stratified 80/10/10 split  seed=42.
# [2026-04-13 11:35:16] [BiGRU] [INFO]  Training   : 75581 samples  (80.0%)
# [2026-04-13 11:35:16] [BiGRU] [INFO]  Validation : 9448 samples  (10.0%)
# [2026-04-13 11:35:16] [BiGRU] [INFO]  Test       : 9448 samples  (10.0%)

# %% [markdown]
# ## Section 14 — Dataset Construction
#
# Three  pipelines are instantiated from the splits.
# Augmentation and shuffling are applied **only** to the training pipeline.
# Steps-per-epoch are derived from split sizes and batch size.

# %%
train_dataset = get_parquet_dataset(
    train_df_split, data_dir=CFG.DATA_DIR, batch_size=CFG.BATCH_SIZE,
    max_len=MAX_LEN, augment=True, shuffle=True,
)
val_dataset = get_parquet_dataset(
    val_df_split, data_dir=CFG.DATA_DIR, batch_size=CFG.BATCH_SIZE,
    max_len=MAX_LEN, augment=False, shuffle=False,
)
test_dataset = get_parquet_dataset(
    test_df_split, data_dir=CFG.DATA_DIR, batch_size=CFG.BATCH_SIZE,
    max_len=MAX_LEN, augment=False, shuffle=False,
)

steps_per_epoch  = len(train_df_split) // CFG.BATCH_SIZE
validation_steps = len(val_df_split)   // CFG.BATCH_SIZE
test_steps       = len(test_df_split)  // CFG.BATCH_SIZE

logger.info("Steps/epoch: %d  |  Val steps: %d  |  Test steps: %d",
            steps_per_epoch, validation_steps, test_steps)
# Out:
# [2026-04-13 11:35:16] [BiGRU] [INFO]  Steps/epoch: 590  |  Val steps: 73  |  Test steps: 73

# %% [markdown]
# ## Section 15 — Pre-Training Dataset Report
#
# A statistical summary of the split is saved to disk and visualised as
# a pie chart (allocation) and bar chart (per-class sample count).

# %%
_tc = train_df_split["label"].value_counts()
_vc = val_df_split  ["label"].value_counts()
_xc = test_df_split ["label"].value_counts()

_report = (
    f"=========================================================\n"
    f"       DATASET REPORT — {CFG.MODEL_NAME}\n"
    f"=========================================================\n"
    f"Total sequences         : {len(train_df)}\n"
    f"Unique classes          : {NUM_CLASSES}\n"
    f"Selected landmark nodes : {NUM_NODES}\n"
    f"Feature channels        : {CHANNELS}\n"
    f"Max sequence length     : {MAX_LEN} frames\n"
    f"Input tensor shape      : (Batch, {MAX_LEN}, {CHANNELS})\n"
    f"---------------------------------------------------------\n"
    f"Training   : {len(train_df_split)} samples\n"
    f"Validation : {len(val_df_split)} samples\n"
    f"Test       : {len(test_df_split)} samples\n"
    f"---------------------------------------------------------\n"
    f"[Train] max={_tc.max()}  min={_tc.min()}  mean={_tc.mean():.1f}\n"
    f"[Val]   max={_vc.max()}  min={_vc.min()}  mean={_vc.mean():.1f}\n"
    f"[Test]  max={_xc.max()}  min={_xc.min()}  mean={_xc.mean():.1f}\n"
    f"=========================================================\n"
)
logger.info(_report)

with open(os.path.join(DIRS["metrics"], "dataset_report.txt"), "w") as _f:
    _f.write(_report)

_fig, (_ax1, _ax2) = plt.subplots(1, 2, figsize=(14, 6))
_ax1.pie(
    [len(train_df_split), len(val_df_split), len(test_df_split)],
    labels=["Training (80%)", "Validation (10%)", "Test (10%)"],
    colors=["#4285F4", "#34A853", "#FBBC05"],
    autopct="%1.1f%%", startangle=90, textprops={"fontsize": 12},
)
_ax1.set_title("Dataset Allocation", fontsize=14, fontweight="bold")

_means = [_tc.mean(), _vc.mean(), _xc.mean()]
_ax2.bar(["Train", "Validation", "Test"], _means,
         color=["#4285F4", "#34A853", "#FBBC05"], width=0.5)
_ax2.set_ylabel("Mean Sequences per Class")
_ax2.set_title("Average Class Representation", fontsize=14, fontweight="bold")
for _i, _v in enumerate(_means):
    _ax2.text(_i, _v + 1, f"{_v:.1f}", ha="center", fontweight="bold")

plt.tight_layout()
plt.savefig(os.path.join(DIRS["plots"], "data_split_distribution.png"), dpi=300, bbox_inches="tight")
plt.show()
logger.info("Pre-training report saved.")
# Out:
# [2026-04-13 11:35:16] [BiGRU] [INFO]  =========================================================
#        DATASET REPORT — BiGRU
# =========================================================
# Total sequences         : 94477
# Unique classes          : 250
# Selected landmark nodes : 118
# Feature channels        : 708
# Max sequence length     : 384 frames
# Input tensor shape      : (Batch, 384, 708)
# ---------------------------------------------------------
# Training   : 75581 samples
# Validation : 9448 samples
# Test       : 9448 samples
# ---------------------------------------------------------
# [Train] max=332  min=239  mean=302.3
# [Val]   max=42  min=30  mean=37.8
# [Test]  max=41  min=30  mean=37.8
# =========================================================
# [2026-04-13 11:35:17] [BiGRU] [INFO]  Pre-training report saved.

# %% [markdown]
# ## **Section 16 — Model Architecture: Enhanced BiGRU**
#
# The enhanced Bidirectional GRU architecture builds on a strong sequence modeling baseline with additional mechanisms for better feature extraction and generalisation:
#
# * **Masking** — padded timesteps (sentinel value) are excluded from computation before entering the network
#
# * **Stem Projection**
#   A dense projection layer maps input features into a higher-level representation space (`dim`), followed by:
#
#   * Batch Normalization
#   * Swish activation
#   * SpatialDropout1D for temporal regularisation
#
# * **Stacked Bidirectional GRU Layers**
#   Two BiGRU blocks are used to capture both forward and backward temporal dependencies:
#
#   * First layer: higher dimensional representation
#   * Second layer: compressed representation
#   * Each block is followed by **Layer Normalization** for stable training
#
# * **Attention Mechanism**
#   A lightweight attention layer is applied over the temporal dimension to:
#
#   * Learn importance weights across timesteps
#   * Focus on the most informative parts of the sequence
#   * Produce a weighted representation via attention pooling
#
# * **Multi-View Temporal Aggregation**
#   Instead of relying on a single pooling strategy, the model combines:
#
#   * Attention-based representation
#   * Global Average Pooling (captures overall trends)
#   * Global Max Pooling (captures strong signals)
#
#   These representations are concatenated to form a richer feature vector.
#
# * **Classification Head**
#   The aggregated features pass through:
#
#   * Dense layer with Swish activation
#   * Batch Normalization
#   * Dropout for regularisation
#
# * **Output Layer (AMP-safe)**
#   Final dense layer outputs raw logits with `float32` precision to ensure numerical stability during mixed precision training.
#
#
#
# ### **Model Flexibility**
#
# To experiment with different architectures:
#
# * Define a new `get_model()` function
# * Update `CFG.MODEL_NAME` and model reference
#
# All downstream training, logging, checkpointing, and evaluation pipelines will adapt automatically without any changes to the data processing pipeline.

# %%
class MaskableConv1D(layers.Conv1D):
    """Conv1D that propagates the padding mask to downstream layers."""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.supports_masking = True


class Squeeze(layers.Layer):
    """Removes a given axis. Replaces Lambda(tf.squeeze) with masking support."""
    def __init__(self, axis, **kwargs):
        super().__init__(**kwargs)
        self.axis = axis
        self.supports_masking = True

    def call(self, x):
        return tf.squeeze(x, axis=self.axis)

    def get_config(self):
        return {**super().get_config(), "axis": self.axis}


class ExpandDims(layers.Layer):
    """Adds a given axis. Replaces Lambda(tf.expand_dims) with masking support."""
    def __init__(self, axis, **kwargs):
        super().__init__(**kwargs)
        self.axis = axis
        self.supports_masking = True

    def call(self, x):
        return tf.expand_dims(x, axis=self.axis)

    def get_config(self):
        return {**super().get_config(), "axis": self.axis}


class ReduceSum(layers.Layer):
    """Reduces along a given axis. Replaces Lambda(tf.reduce_sum)."""
    def __init__(self, axis, **kwargs):
        super().__init__(**kwargs)
        self.axis = axis
        self.supports_masking = True

    def call(self, x):
        return tf.reduce_sum(x, axis=self.axis)

    def get_config(self):
        return {**super().get_config(), "axis": self.axis}


class MaskableGlobalMaxPool1D(layers.GlobalMaxPooling1D):
    """GlobalMaxPooling1D that propagates the padding mask."""
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.supports_masking = True


def get_model(max_len, channels, num_classes, dim=256, dropout_rate=0.4):
    inp = layers.Input(shape=(max_len, channels), name="input_features")

    # ── Masking ────────────────────────────────────────────────────────────────
    x = layers.Masking(mask_value=-100.0, name="masking")(inp)

    # ── Conv1D Stem ────────────────────────────────────────────────────────────
    # MaskableConv1D preserves the padding mask for all downstream layers.
    x = MaskableConv1D(dim, kernel_size=3, padding="same", use_bias=False, name="stem_conv")(x)
    x = layers.BatchNormalization(momentum=0.95, name="stem_bn")(x)
    x = layers.Activation("swish", name="stem_act")(x)
    x = layers.SpatialDropout1D(dropout_rate, name="stem_drop")(x)

    # ── BiGRU Block 1 + Residual ───────────────────────────────────────────────
    # skip1 projects x from dim to dim*2 to match the BiGRU output width.
    skip1 = layers.Dense(dim * 2, use_bias=False, name="skip1_proj")(x)
    x = layers.Bidirectional(
        layers.GRU(dim, return_sequences=True, dropout=0.25, recurrent_dropout=0.0),
        name="bigru_1",
    )(x)
    x = layers.LayerNormalization(epsilon=1e-6, name="ln_1")(x)
    x = layers.Add(name="res_1")([x, skip1])

    # ── BiGRU Block 2 + Residual ───────────────────────────────────────────────
    # skip2 projects the dim*2 input down to dim to match the BiGRU output width.
    skip2 = layers.Dense(dim, use_bias=False, name="skip2_proj")(x)
    x = layers.Bidirectional(
        layers.GRU(dim // 2, return_sequences=True, dropout=0.25, recurrent_dropout=0.0),
        name="bigru_2",
    )(x)
    x = layers.LayerNormalization(epsilon=1e-6, name="ln_2")(x)
    x = layers.Add(name="res_2")([x, skip2])

    # ── Projected Attention ────────────────────────────────────────────────────
    # attn_score shape: (B, T, 1).
    # Softmax receives the padding mask with shape (B, T) — dimensions must match
    # on the time axis, so we squeeze before Softmax and restore after.
    # FIX: Lambda replaced with Squeeze / ExpandDims (support masking).
    attn = layers.Dense(dim // 4, activation="tanh", name="attn_proj")(x)
    attn = layers.Dense(1, name="attn_score")(attn)                   # (B, T, 1)
    attn = Squeeze(axis=-1, name="attn_squeeze")(attn)                 # (B, T)
    attn = layers.Softmax(axis=1, name="attn_weights")(attn)           # (B, T)
    attn = ExpandDims(axis=-1, name="attn_expand")(attn)               # (B, T, 1)
    x_attn = layers.Multiply(name="attn_apply")([x, attn])             # (B, T, dim)
    x_attn = ReduceSum(axis=1, name="attn_sum")(x_attn)               # (B, dim)

    # ── Pooling Combination ────────────────────────────────────────────────────
    # FIX: MaskableGlobalMaxPool1D instead of GlobalMaxPooling1D.
    gap = layers.GlobalAveragePooling1D(name="gap")(x)
    gmp = MaskableGlobalMaxPool1D(name="gmp")(x)

    # ── Pool Projection ────────────────────────────────────────────────────────
    # Concat produces (B, 3*dim). The projection compresses back to (B, dim)
    # before the head so the head Dense does not carry an unnecessarily large input.
    fused = layers.Concatenate(name="concat")([x_attn, gap, gmp])
    fused = layers.Dense(dim, use_bias=False, name="pool_proj")(fused)
    fused = layers.LayerNormalization(epsilon=1e-6, name="pool_ln")(fused)
    fused = layers.Activation("swish", name="pool_act")(fused)

    # ── Classification Head ────────────────────────────────────────────────────
    x = layers.Dense(dim, activation="swish", use_bias=False, name="head_dense")(fused)
    x = layers.BatchNormalization(momentum=0.95, name="head_bn")(x)
    x = layers.Dropout(dropout_rate + 0.1, name="head_drop")(x)

    # dtype=float32 ensures stable output under mixed precision (AMP).
    outputs = layers.Dense(num_classes, dtype="float32", name="classifier")(x)

    return Model(inputs=inp, outputs=outputs, name=CFG.MODEL_NAME)

# %% [markdown]
# ## Section 17 — Model Initialisation and Architecture Logging
#
# The model is instantiated from the architecture function. Its parameter count
# and layer summary are persisted to the metrics directory. An architecture
# diagram is generated when  and  are available.

# %%
model = get_model(max_len=MAX_LEN, channels=CHANNELS, num_classes=NUM_CLASSES)
model.summary(print_fn=logger.info)

_params    = model.count_params()
_trainable = sum(tf.keras.backend.count_params(w) for w in model.trainable_weights)
with open(os.path.join(DIRS["metrics"], "model_params.txt"), "w") as _f:
    _f.write(f"Total parameters    : {_params:,}\n")
    _f.write(f"Trainable parameters: {_trainable:,}\n")

logger.info("Parameters — total: %s  trainable: %s", f"{_params:,}", f"{_trainable:,}")

try:
    _diag_path = os.path.join(DIRS["plots"], f"{CFG.MODEL_NAME}_architecture.png")
    plot_model(model, to_file=_diag_path, show_shapes=True, show_layer_names=True, dpi=150)
    logger.info("Architecture diagram saved: %s", _diag_path)
except Exception as _e:
    logger.warning("Architecture diagram skipped (pydot/graphviz required): %s", _e)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [2026-04-13 11:35:19] [BiGRU] [INFO]  Model: "BiGRU"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_features      │ (None, 384, 708)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ cast (Cast)         │ (None, 384, 708)  │          0 │ input_features[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ masking (Masking)   │ (None, 384, 708)  │          0 │ input_features[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal           │ (None, 384, 708)  │          0 │ cast[0][0]        │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv           │ (None, 384, 256)  │    543,744 │ masking[0][0]     │
# │ (MaskableConv1D)    │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any (Any)           │ (None, 384)       │          0 │ not_equal[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 384, 256)  │      1,024 │ stem_conv[0][0],  │
# │ (BatchNormalizatio… │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_act            │ (None, 384, 256)  │          0 │ stem_bn[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_drop           │ (None, 384, 256)  │          0 │ stem_act[0][0]    │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bigru_1             │ (None, 384, 512)  │    789,504 │ stem_drop[0][0],  │
# │ (Bidirectional)     │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_1                │ (None, 384, 512)  │      1,024 │ bigru_1[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip1_proj (Dense)  │ (None, 384, 512)  │    131,072 │ stem_drop[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ res_1 (Add)         │ (None, 384, 512)  │          0 │ ln_1[0][0],       │
# │                     │                   │            │ skip1_proj[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ logical_or          │ (None, 384)       │          0 │ any[0][0],        │
# │ (LogicalOr)         │                   │            │ any[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bigru_2             │ (None, 384, 256)  │    493,056 │ res_1[0][0],      │
# │ (Bidirectional)     │                   │            │ logical_or[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ln_2                │ (None, 384, 256)  │        512 │ bigru_2[0][0]     │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ skip2_proj (Dense)  │ (None, 384, 256)  │    131,072 │ res_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ res_2 (Add)         │ (None, 384, 256)  │          0 │ ln_2[0][0],       │
# │                     │                   │            │ skip2_proj[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_proj (Dense)   │ (None, 384, 64)   │     16,448 │ res_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_score (Dense)  │ (None, 384, 1)    │         65 │ attn_proj[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_squeeze        │ (None, 384)       │          0 │ attn_score[0][0]  │
# │ (Squeeze)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ logical_or_1        │ (None, 384)       │          0 │ logical_or[0][0], │
# │ (LogicalOr)         │                   │            │ logical_or[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_weights        │ (None, 384)       │          0 │ attn_squeeze[0][… │
# │ (Softmax)           │                   │            │ logical_or_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_expand         │ (None, 384, 1)    │          0 │ attn_weights[0][… │
# │ (ExpandDims)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_apply          │ (None, 384, 256)  │          0 │ res_2[0][0],      │
# │ (Multiply)          │                   │            │ attn_expand[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ attn_sum            │ (None, 256)       │          0 │ attn_apply[0][0]  │
# │ (ReduceSum)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gap                 │ (None, 256)       │          0 │ res_2[0][0],      │
# │ (GlobalAveragePool… │                   │            │ logical_or_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ gmp                 │ (None, 256)       │          0 │ res_2[0][0]       │
# │ (MaskableGlobalMax… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concat              │ (None, 768)       │          0 │ attn_sum[0][0],   │
# │ (Concatenate)       │                   │            │ gap[0][0],        │
# │                     │                   │            │ gmp[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_proj (Dense)   │ (None, 256)       │    196,608 │ concat[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_ln             │ (None, 256)       │        512 │ pool_proj[0][0]   │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ logical_or_2        │ (None, 384)       │          0 │ logical_or_1[0][… │
# │ (LogicalOr)         │                   │            │ logical_or_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ ones_like           │ (None, 256)       │          0 │ gap[0][0]         │
# │ (OnesLike)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool_act            │ (None, 256)       │          0 │ pool_ln[0][0]     │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 1024)      │          0 │ logical_or_2[0][… │
# │ (Concatenate)       │                   │            │ ones_like[0][0],  │
# │                     │                   │            │ logical_or_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_dense (Dense)  │ (None, 256)       │     65,536 │ pool_act[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ any_1 (Any)         │ (None)            │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_bn             │ (None, 256)       │      1,024 │ head_dense[0][0], │
# │ (BatchNormalizatio… │                   │            │ any_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ head_drop (Dropout) │ (None, 256)       │          0 │ head_bn[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ classifier (Dense)  │ (None, 250)       │     64,250 │ head_drop[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 2,435,451 (9.29 MB)
#  Trainable params: 2,434,427 (9.29 MB)
#  Non-trainable params: 1,024 (4.00 KB)
#
# [2026-04-13 11:35:19] [BiGRU] [INFO]  Parameters — total: 2,435,451  trainable: 2,434,427
# [2026-04-13 11:35:21] [BiGRU] [INFO]  Architecture diagram saved: /kaggle/working/BiGRU/plots/BiGRU_architecture.png

# %% [markdown]
# ## Section 18 — Learning Rate Schedule and Optimiser
#
# A cosine-decay schedule with linear warm-up is implemented as a
#  subclass.  Because the schedule is a function of the
# **global optimiser step** (not the epoch counter), it resumes seamlessly from
# a checkpoint — the learning rate and momentum buffers are both restored.
#
#  wraps the base Adam optimiser when AMP is enabled to
# prevent FP16 underflow during backpropagation.

# %%
# ── Section 18 — Learning Rate Schedule and Optimiser ────────────────────────
# WarmupCosineDecay is defined here as a LearningRateSchedule subclass so it
# is keyed to the global optimizer step, not the epoch counter. This means the
# schedule continues correctly after a checkpoint restore with no offset fix.
# ─────────────────────────────────────────────────────────────────────────────

class WarmupCosineDecay(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, peak_lr, total_steps, warmup_steps, min_lr=CFG.MIN_LR):
        super().__init__()
        self.peak_lr      = float(peak_lr)
        self.total_steps  = float(total_steps)
        self.warmup_steps = float(warmup_steps)
        self.min_lr       = float(min_lr)

    def __call__(self, step):
        step      = tf.cast(step, tf.float32)
        warmup    = self.peak_lr * step / tf.maximum(self.warmup_steps, 1.0)
        cos_input = (step - self.warmup_steps) / tf.maximum(
            self.total_steps - self.warmup_steps, 1.0
        ) * math.pi
        cos_decay = self.min_lr + 0.5 * (self.peak_lr - self.min_lr) * (
            1.0 + tf.math.cos(cos_input)
        )
        return tf.where(step < self.warmup_steps, warmup, cos_decay)

    def get_config(self):
        return {
            "peak_lr":      self.peak_lr,
            "total_steps":  self.total_steps,
            "warmup_steps": self.warmup_steps,
            "min_lr":       self.min_lr,
        }


_total_steps  = steps_per_epoch * CFG.EPOCHS
_warmup_steps = int(_total_steps * CFG.WARMUP_RATIO)

lr_schedule = WarmupCosineDecay(CFG.LEARNING_RATE, _total_steps, _warmup_steps, CFG.MIN_LR)
optimizer   = optimizers.Adam(learning_rate=lr_schedule)
loss_fn     = losses.CategoricalCrossentropy(from_logits=True, label_smoothing=CFG.LABEL_SMOOTHING)

logger.info("Optimiser : Adam + WarmupCosineDecay")
logger.info("Peak LR   : %.2e  |  Min LR: %.2e  |  Warm-up steps: %d",
            CFG.LEARNING_RATE, CFG.MIN_LR, _warmup_steps)
# Out:
# [2026-04-13 11:35:21] [BiGRU] [INFO]  Optimiser : Adam + WarmupCosineDecay
# [2026-04-13 11:35:21] [BiGRU] [INFO]  Peak LR   : 1.00e-03  |  Min LR: 1.00e-06  |  Warm-up steps: 2950

# %% [markdown]
# ## Section 19 — Checkpointing and Resume Logic
#
#  saves model weights and the full optimiser state
# (including the LR schedule step counter) atomically.  On restart:
#
# 1. The pipeline scans  for an existing checkpoint.
# 2. If found, model weights, optimiser state, and epoch counter are restored.
# 3. Training resumes from the correct epoch with the LR exactly as left.
#
# Two checkpoints are maintained:
#
# | Directory | Trigger |
# |---|---|
# |  | Saved at the end of every epoch |
# |  | Saved when validation accuracy improves |

# %%
# ── Section 19 — Checkpointing and Resume Logic ───────────────────────────────
# tf.train.Checkpoint saves model weights and the full optimizer state
# (including the LR schedule step counter) atomically. On restart:
#   1. Scans checkpoints/last/ for an existing checkpoint.
#   2. If found AND the files physically exist, restores everything.
#   3. If the checkpoint index exists but the files are missing (e.g. after
#      a Kaggle session reset), clears the stale index and starts fresh.
#   4. If CFG.RESET_CHECKPOINT=True, wipes everything before starting.
# ─────────────────────────────────────────────────────────────────────────────

import shutil

_ckpt_dir_last = os.path.join(DIRS["checkpoints"], "last")
_ckpt_dir_best = os.path.join(DIRS["checkpoints"], "best")
os.makedirs(_ckpt_dir_last, exist_ok=True)
os.makedirs(_ckpt_dir_best, exist_ok=True)

epoch_var    = tf.Variable(0,   trainable=False, dtype=tf.int64,   name="epoch")
best_val_acc = tf.Variable(0.0, trainable=False, dtype=tf.float32, name="best_val_acc")

checkpoint   = tf.train.Checkpoint(
    model=model,
    optimizer=optimizer,
    epoch=epoch_var,
    best_val_acc=best_val_acc,
)
manager_last = tf.train.CheckpointManager(checkpoint, _ckpt_dir_last, max_to_keep=2)
manager_best = tf.train.CheckpointManager(checkpoint, _ckpt_dir_best, max_to_keep=1)


def _checkpoint_files_exist(manager):
    """Returns True only if the checkpoint index file physically exists on disk."""
    latest = manager.latest_checkpoint
    if latest is None:
        return False
    return os.path.exists(latest + ".index")


# Wipe stale or incompatible checkpoints when requested via config.
if CFG.RESET_CHECKPOINT:
    shutil.rmtree(_ckpt_dir_last, ignore_errors=True)
    shutil.rmtree(_ckpt_dir_best, ignore_errors=True)
    os.makedirs(_ckpt_dir_last, exist_ok=True)
    os.makedirs(_ckpt_dir_best, exist_ok=True)
    # Re-create managers after wiping so their internal state is clean.
    manager_last = tf.train.CheckpointManager(checkpoint, _ckpt_dir_last, max_to_keep=2)
    manager_best = tf.train.CheckpointManager(checkpoint, _ckpt_dir_best, max_to_keep=1)
    logger.info("RESET_CHECKPOINT=True — all checkpoints cleared.")

initial_epoch = 0

if not _checkpoint_files_exist(manager_last):
    # Covers three cases:
    #   a) No checkpoint was ever saved (fresh run).
    #   b) Kaggle session reset wiped /kaggle/working but the manager
    #      still holds a stale path in its checkpoint file.
    #   c) CFG.RESET_CHECKPOINT just cleared everything above.
    if manager_last.latest_checkpoint is not None:
        # Stale index — clear it so future saves start from ckpt-1.
        shutil.rmtree(_ckpt_dir_last, ignore_errors=True)
        shutil.rmtree(_ckpt_dir_best, ignore_errors=True)
        os.makedirs(_ckpt_dir_last, exist_ok=True)
        os.makedirs(_ckpt_dir_best, exist_ok=True)
        manager_last = tf.train.CheckpointManager(checkpoint, _ckpt_dir_last, max_to_keep=2)
        manager_best = tf.train.CheckpointManager(checkpoint, _ckpt_dir_best, max_to_keep=1)
        logger.warning("Stale checkpoint index found but files are missing — cleared and starting fresh.")
    else:
        logger.info("No checkpoint found — starting fresh training.")
else:
    try:
        checkpoint.restore(manager_last.latest_checkpoint)
        initial_epoch = int(epoch_var.numpy())
        logger.info("Checkpoint restored: %s — resuming from epoch %d.",
                    manager_last.latest_checkpoint, initial_epoch + 1)
    except Exception as _e:
        logger.error("Checkpoint restore failed (%s) — starting fresh.", _e)
        shutil.rmtree(_ckpt_dir_last, ignore_errors=True)
        shutil.rmtree(_ckpt_dir_best, ignore_errors=True)
        os.makedirs(_ckpt_dir_last, exist_ok=True)
        os.makedirs(_ckpt_dir_best, exist_ok=True)
        manager_last = tf.train.CheckpointManager(checkpoint, _ckpt_dir_last, max_to_keep=2)
        manager_best = tf.train.CheckpointManager(checkpoint, _ckpt_dir_best, max_to_keep=1)
        initial_epoch = 0
# Out:
# [2026-04-13 11:35:21] [BiGRU] [INFO]  Checkpoint restored: /kaggle/working/BiGRU/checkpoints/last/ckpt-165 — resuming from epoch 101.

# %% [markdown]
# ## Section 20 — Stateful Metric Objects
#
# Stateful Keras metric objects accumulate values over a full epoch and are
# reset at the start of each epoch. This is correct even when gradient
# accumulation splits one nominal epoch into multiple micro-steps.

# %%
train_loss_m  = metrics.Mean(name="loss")
train_acc_m   = metrics.CategoricalAccuracy(name="accuracy")
train_top5_m  = metrics.TopKCategoricalAccuracy(k=5, name="top_5_accuracy")

val_loss_m    = metrics.Mean(name="val_loss")
val_acc_m     = metrics.CategoricalAccuracy(name="val_accuracy")
val_top5_m    = metrics.TopKCategoricalAccuracy(k=5, name="val_top_5_accuracy")

# %% [markdown]
# ## Section 21 — Custom Training and Validation Steps
#
#  implements one forward pass with optional gradient accumulation
# and one optimiser update.  When , gradients are
# summed across micro-batches before weights are updated, simulating a larger
# effective batch size.
#
# The AMP path uses  /  to prevent
# FP16 underflow during backpropagation.  Gradients are clipped by global norm
# before the optimiser step to ensure training stability.

# %%
@tf.function
def train_step(x_batch, y_batch, accum_grads, step_in_accum):
    with tf.GradientTape() as tape:
        y_pred   = model(x_batch, training=True)
        raw_loss = loss_fn(y_batch, y_pred)
        # Divide by accumulation steps so the effective loss magnitude is consistent
        # regardless of how many micro-batches are accumulated before the update.
        scaled   = raw_loss / tf.cast(CFG.GRAD_ACCUM_STEPS, raw_loss.dtype)

    grads     = tape.gradient(scaled, model.trainable_variables)
    new_accum = [ag + g for ag, g in zip(accum_grads, grads)]

    if tf.equal(step_in_accum, CFG.GRAD_ACCUM_STEPS - 1):
        clipped, _ = tf.clip_by_global_norm(new_accum, 1.0)
        optimizer.apply_gradients(zip(clipped, model.trainable_variables))
        new_accum  = [tf.zeros_like(v) for v in model.trainable_variables]

    train_loss_m.update_state(raw_loss)
    train_acc_m .update_state(y_batch, y_pred)
    train_top5_m.update_state(y_batch, y_pred)
    return new_accum


@tf.function
def val_step(x_batch, y_batch):
    y_pred = model(x_batch, training=False)
    val_loss_m.update_state(loss_fn(y_batch, y_pred))
    val_acc_m .update_state(y_batch, y_pred)
    val_top5_m.update_state(y_batch, y_pred)

# %% [markdown]
# ## Section 22 — Training Loop with Fail-Safe Execution
#
# The main loop:
#
# 1. Resets all metric objects at the start of each epoch.
# 2. Runs training micro-batches with gradient accumulation.
# 3. Runs all validation batches.
# 4. Logs per-epoch metrics and appends them to a CSV history file.
# 5. Saves the last-epoch checkpoint unconditionally.
# 6. Saves the best-model checkpoint when validation accuracy improves.
# 7. Triggers early stopping after  epochs without improvement.
#
# The loop is wrapped in a  block. On any exception the last
# checkpoint is saved before the exception propagates so no progress is lost.

# %%
def run_training():
    history_rows   = []
    early_stop_ctr = 0
    history_csv    = os.path.join(DIRS["metrics"], f"{CFG.MODEL_NAME}_training_history.csv")

    if os.path.exists(history_csv):
        history_rows = pd.read_csv(history_csv).to_dict("records")
        logger.info("Loaded %d existing history rows from CSV.", len(history_rows))

    accum_grads = [tf.zeros_like(v) for v in model.trainable_variables]

    for epoch in range(initial_epoch, CFG.EPOCHS):
        t0 = time.time()

        for m in [train_loss_m, train_acc_m, train_top5_m,
                  val_loss_m,   val_acc_m,   val_top5_m]:
            m.reset_state()

        # Training phase
        for step, (xb, yb) in enumerate(train_dataset.take(steps_per_epoch)):
            accum_grads = train_step(xb, yb, accum_grads, step % CFG.GRAD_ACCUM_STEPS)

        # Validation phase
        for xb, yb in val_dataset.take(validation_steps):
            val_step(xb, yb)

        t_loss = float(train_loss_m.result());  t_acc = float(train_acc_m.result());  t_top5 = float(train_top5_m.result())
        v_loss = float(val_loss_m  .result());  v_acc = float(val_acc_m  .result());  v_top5 = float(val_top5_m  .result())
        elapsed = time.time() - t0

        logger.info(
            "Epoch %03d/%03d | loss=%.4f acc=%.4f top5=%.4f | "            "val_loss=%.4f val_acc=%.4f val_top5=%.4f | %.1fs",
            epoch + 1, CFG.EPOCHS, t_loss, t_acc, t_top5, v_loss, v_acc, v_top5, elapsed,
        )

        row = {"epoch": epoch + 1,
               "loss": t_loss, "accuracy": t_acc, "top_5_accuracy": t_top5,
               "val_loss": v_loss, "val_accuracy": v_acc, "val_top_5_accuracy": v_top5,
               "elapsed_s": elapsed}
        history_rows.append(row)
        pd.DataFrame(history_rows).to_csv(history_csv, index=False)

        epoch_var.assign(epoch + 1)
        manager_last.save()

        if v_acc > float(best_val_acc.numpy()):
            best_val_acc.assign(v_acc)
            manager_best.save()
            logger.info("  Best model saved — val_accuracy=%.4f", v_acc)
            early_stop_ctr = 0
        else:
            early_stop_ctr += 1
            logger.info("  No improvement for %d/%d epochs.", early_stop_ctr, CFG.EARLY_STOP_PAT)
            if early_stop_ctr >= CFG.EARLY_STOP_PAT:
                logger.info("Early stopping triggered at epoch %d.", epoch + 1)
                break

    return pd.DataFrame(history_rows)


try:
    history_df = run_training()
    logger.info("Training completed successfully.")
except KeyboardInterrupt:
    logger.warning("Interrupted by user — saving emergency checkpoint.")
    manager_last.save()
    history_df = None
except Exception as _exc:
    logger.error("Training failed: %s", _exc)
    logger.error(traceback.format_exc())
    try:
        manager_last.save()
        logger.info("Emergency checkpoint saved.")
    except Exception as _e2:
        logger.error("Emergency checkpoint also failed: %s", _e2)
    raise
# Out:
# [2026-04-13 11:35:21] [BiGRU] [INFO]  Loaded 100 existing history rows from CSV.
# [2026-04-13 11:35:21] [BiGRU] [INFO]  Training completed successfully.

# %% [markdown]
# ## Section 23 — Training History Visualisation
#
# Loss and accuracy curves are plotted from the CSV history file.
# Using the CSV (rather than the in-memory object) ensures plots are correct
# even when training was resumed across multiple Kaggle sessions.

# %%
_history_csv = os.path.join(DIRS["metrics"], f"{CFG.MODEL_NAME}_training_history.csv")

if os.path.exists(_history_csv):
    _hist = pd.read_csv(_history_csv)

    _fig, _axes = plt.subplots(1, 2, figsize=(16, 5))
    _fig.suptitle(f"{CFG.MODEL_NAME} — Training History", fontsize=14, fontweight="bold")

    _axes[0].plot(_hist["epoch"], _hist["accuracy"],     label="Train",      color="#4285F4", lw=2)
    _axes[0].plot(_hist["epoch"], _hist["val_accuracy"], label="Validation", color="#34A853", lw=2)
    _axes[0].set_title("Accuracy"); _axes[0].set_xlabel("Epoch"); _axes[0].set_ylabel("Accuracy")
    _axes[0].legend(); _axes[0].grid(True, ls="--", alpha=0.6)

    _axes[1].plot(_hist["epoch"], _hist["loss"],     label="Train",      color="#EA4335", lw=2)
    _axes[1].plot(_hist["epoch"], _hist["val_loss"], label="Validation", color="#FBBC05", lw=2)
    _axes[1].set_title("Loss"); _axes[1].set_xlabel("Epoch"); _axes[1].set_ylabel("Loss")
    _axes[1].legend(); _axes[1].grid(True, ls="--", alpha=0.6)

    plt.tight_layout()
    _plot_path = os.path.join(DIRS["plots"], f"{CFG.MODEL_NAME}_training_history.png")
    plt.savefig(_plot_path, dpi=300, bbox_inches="tight")
    plt.show()
    logger.info("Training history plot saved: %s", _plot_path)
else:
    logger.warning("History CSV not found — skipping plot.")
# Out:
# [2026-04-13 11:35:23] [BiGRU] [INFO]  Training history plot saved: /kaggle/working/BiGRU/plots/BiGRU_training_history.png

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Section 27 — Final Model Export
# ══════════════════════════════════════════════════════════════════════════════

import os, json, shutil, zipfile
import tensorflow as tf

# -- Names --------------------------------------------------------------------
MODEL_NAME   = CFG.MODEL_NAME
FINAL_NAME   = f"final_model_{MODEL_NAME}"
FINAL_FOLDER = os.path.join(CFG.WORKING_DIR, FINAL_NAME)
FINAL_ZIP    = FINAL_FOLDER + ".zip"

if os.path.exists(FINAL_FOLDER):
    shutil.rmtree(FINAL_FOLDER)
os.makedirs(FINAL_FOLDER)

# -- Restore best checkpoint --------------------------------------------------
checkpoint.restore(manager_best.latest_checkpoint)

# -- 1. SavedModel (self-contained, no extra code needed at inference) ---------
_sm_path = os.path.join(FINAL_FOLDER, FINAL_NAME)
model.export(_sm_path)

# -- 2. TFLite (mobile) -------------------------------------------------------
_tflite_path = os.path.join(FINAL_FOLDER, FINAL_NAME + ".tflite")
try:
    _conv = tf.lite.TFLiteConverter.from_saved_model(_sm_path)
    _conv.target_spec.supported_ops = [
        tf.lite.OpsSet.TFLITE_BUILTINS,
        tf.lite.OpsSet.SELECT_TF_OPS,
    ]
    with open(_tflite_path, "wb") as f:
        f.write(_conv.convert())
except Exception as e:
    print(f"TFLite skipped: {e}")

# -- 3. Keras (cross-platform) ------------------------------------------------
_keras_path = os.path.join(FINAL_FOLDER, FINAL_NAME + ".keras")
try:
    model.save(_keras_path)
except Exception as e:
    print(f"Keras skipped: {e}")

# -- Labels -------------------------------------------------------------------
_labels_dst = os.path.join(FINAL_FOLDER, "sign_to_prediction_index_map.json")
if os.path.exists(CFG.SIGN_MAP):
    shutil.copy(CFG.SIGN_MAP, _labels_dst)
else:
    with open(_labels_dst, "w") as f:
        json.dump(sign_to_label, f, ensure_ascii=False, indent=2)

# -- model_info.json ----------------------------------------------------------
with open(os.path.join(FINAL_FOLDER, "model_info.json"), "w") as f:
    json.dump({
        "model_name":     MODEL_NAME,
        "num_classes":    CFG.NUM_CLASSES,
        "max_len":        CFG.MAX_LEN,
        "rows_per_frame": CFG.ROWS_PER_FRAME,
        "pad_value":      CFG.PAD_VALUE,
        "labels_file":    "sign_to_prediction_index_map.json",
        "load": {
            "saved_model": f"tf.saved_model.load('{_sm_path}')",
            "keras":       f"tf.keras.models.load_model('{_keras_path}')",
            "tflite":      f"tf.lite.Interpreter(model_path='{_tflite_path}')",
        }
    }, f, indent=2)

# -- Zip ----------------------------------------------------------------------
if os.path.exists(FINAL_ZIP):
    os.remove(FINAL_ZIP)
with zipfile.ZipFile(FINAL_ZIP, "w", zipfile.ZIP_DEFLATED) as zf:
    for root, _, files in os.walk(FINAL_FOLDER):
        for file in files:
            fp = os.path.join(root, file)
            zf.write(fp, os.path.relpath(fp, os.path.dirname(FINAL_FOLDER)))

print(f"Export complete: {FINAL_ZIP}  ({os.path.getsize(FINAL_ZIP)/1e6:.1f} MB)")
print(f"Load:  model = tf.saved_model.load('{_sm_path}')")
# Out:
# INFO:absl:Function `__call__` contains input name(s) resource with unsupported characters which will be renamed to bigru_1_classifier_1_biasadd_readvariableop_resource in the SavedModel.
# INFO:absl:Function `__call__` contains input name(s) resource with unsupported characters which will be renamed to bigru_1_classifier_1_biasadd_readvariableop_resource in the SavedModel.
# INFO:tensorflow:Assets written to: /kaggle/working/final_model_BiGRU/final_model_BiGRU/assets
# INFO:tensorflow:Assets written to: /kaggle/working/final_model_BiGRU/final_model_BiGRU/assets
# Saved artifact at '/kaggle/working/final_model_BiGRU/final_model_BiGRU'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 384, 708), dtype=tf.float32, name='input_features')
# Output Type:
#   TensorSpec(shape=(None, 250), dtype=tf.float32, name=None)
# Captures:
#   140145609013584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140145609005712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140145609011472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140145609012432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140145609015120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851503440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851504592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851504208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851505936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851503824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851506512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851506320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851505360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851504976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851507088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851501904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851506128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851506704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851507280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851508624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851505552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851509200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851509008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851508048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851505168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851509776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851506896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851504784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851509392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851510160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851508240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851510544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851510352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851511120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851509968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851510928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851507856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851508816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851511696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851509584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140144851511504: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite skipped: Could not translate MLIR to FlatBuffer.<unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/backward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/backward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): see current operation: %1:5 = "tf.CudnnRNNV3"(%arg0, %arg1, %arg2, %arg3, %arg4) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/backward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/forward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/forward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): see current operation: %1:5 = "tf.CudnnRNNV3"(%arg0, %arg1, %arg2, %arg3, %arg4) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/forward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/backward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/backward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): see current operation: %1:5 = "tf.CudnnRNNV3"(%arg0, %arg1, %arg2, %arg3, %arg4) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/backward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/forward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# <unknown>:0: note: loc(fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"]): called from
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/forward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): see current operation: %1:5 = "tf.CudnnRNNV3"(%arg0, %arg1, %arg2, %arg3, %arg4) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
# <unknown>:0: note: loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/forward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): Error code: ERROR_NEEDS_CUSTOM_OPS
# <unknown>:0: error: failed while converting: 'main':
# Some ops in the model are custom ops, See instructions to implement custom ops: https://www.tensorflow.org/lite/guide/ops_custom
# Custom ops: CudnnRNNV3
# Details:
# 	tf.CudnnRNNV3(tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) : {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# 	tf.CudnnRNNV3(tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) : {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
#
# <unknown>:0: note: see current operation:
# "func.func"() <{arg_attrs = [{tf_saved_model.index_path = ["input_features"]}], function_type = (tensor<?x384x708xf32>) -> tensor<?x250xf32>, res_attrs = [{tf_saved_model.index_path = ["output_0"]}], sym_name = "main"}> ({
# ^bb0(%arg0: tensor<?x384x708xf32>):
#   "tfl.call_once"() <{session_init_function = "NoOp"}> : () -> ()
#   %0 = "arith.constant"() <{value = dense<[-1, 384]> : tensor<2xi32>}> : () -> tensor<2xi32>
#   %1 = "arith.constant"() <{value = dense<[-1, 384, 256]> : tensor<3xi32>}> : () -> tensor<3xi32>
#   %2 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<250x256xf32>}> : () -> tensor<250x256xf32>
#   %3 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256x256xf16>}> : () -> tensor<256x256xf16>
#   %4 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256x768xf16>}> : () -> tensor<256x768xf16>
#   %5 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<394752xf16>}> : () -> tensor<394752xf16>
#   %6 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<64x1xf16>}> : () -> tensor<64x1xf16>
#   %7 = "arith.constant"() <{value = dense<-1.750490e-01> : tensor<1xf16>}> : () -> tensor<1xf16>
#   %8 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256x64xf16>}> : () -> tensor<256x64xf16>
#   %9 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<64xf16>}> : () -> tensor<64xf16>
#   %10 = "arith.constant"() <{value = dense<1> : tensor<i32>}> : () -> tensor<i32>
#   %11 = "arith.constant"() <{value = dense<256> : tensor<i32>}> : () -> tensor<i32>
#   %12 = "arith.constant"() <{value = dense<-1.000000e+02> : tensor<f32>}> : () -> tensor<f32>
#   %13 = "arith.constant"() <{value = dense<-1> : tensor<1xi32>}> : () -> tensor<1xi32>
#   %14 = "arith.constant"() <{value = dense<2> : tensor<i32>}> : () -> tensor<i32>
#   %15 = "arith.constant"() <{value = dense<0> : tensor<1xi32>}> : () -> tensor<1xi32>
#   %16 = "arith.constant"() <{value = dense<1> : tensor<1xi32>}> : () -> tensor<1xi32>
#   %17 = "arith.constant"() <{value = dense<-1> : tensor<i32>}> : () -> tensor<i32>
#   %18 = "arith.constant"() <{value = dense<-3.000000e+04> : tensor<f16>}> : () -> tensor<f16>
#   %19 = "arith.constant"() <{value = dense<1.000000e+00> : tensor<f16>}> : () -> tensor<f16>
#   %20 = "arith.constant"() <{value = dense<[0, 1]> : tensor<2xi64>}> : () -> tensor<2xi64>
#   %21 = "arith.constant"() <{value = dense<0.000000e+00> : tensor<f16>}> : () -> tensor<f16>
#   %22 = "arith.constant"() <{value = dense<128> : tensor<i32>}> : () -> tensor<i32>
#   %23 = "arith.constant"() <{value = dense<9.99999997E-7> : tensor<f32>}> : () -> tensor<f32>
#   %24 = "arith.constant"() <{value = dense<-3> : tensor<i32>}> : () -> tensor<i32>
#   %25 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<250xf32>}> : () -> tensor<250xf32>
#   %26 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<394752xf16>}> : () -> tensor<394752xf16>
#   %27 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<246528xf16>}> : () -> tensor<246528xf16>
#   %28 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<246528xf16>}> : () -> tensor<246528xf16>
#   %29 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256xf32>}> : () -> tensor<256xf32>
#   %30 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256xf32>}> : () -> tensor<256xf32>
#   %31 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x1x512xf32>}> : () -> tensor<1x1x512xf32>
#   %32 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x1x512xf32>}> : () -> tensor<1x1x512xf32>
#   %33 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x1x256xf32>}> : () -> tensor<1x1x256xf32>
#   %34 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x1x256xf32>}> : () -> tensor<1x1x256xf32>
#   %35 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x256xf32>}> : () -> tensor<1x256xf32>
#   %36 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x256xf32>}> : () -> tensor<1x256xf32>
#   %37 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256x512xf16>}> : () -> tensor<256x512xf16>
#   %38 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<512x256xf16>}> : () -> tensor<512x256xf16>
#   %39 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256xf32>}> : () -> tensor<256xf32>
#   %40 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<256xf32>}> : () -> tensor<256xf32>
#   %41 = "arith.constant"() <{value = dense_resource<__elided__> : tensor<1x3x708x256xf16>}> : () -> tensor<1x3x708x256xf16>
#   %42 = "tfl.var_handle"() <{container = "", shared_name = "seed_generator_6/seed_generator_state_1"}> : () -> tensor<!tf_type.resource<tensor<2xi64>>>
#   %43 = "tfl.var_handle"() <{container = "", shared_name = "seed_generator_5/seed_generator_state_1"}> : () -> tensor<!tf_type.resource<tensor<2xi64>>>
#   %44 = "tfl.var_handle"() <{container = "", shared_name = "seed_generator_3/seed_generator_state_1"}> : () -> tensor<!tf_type.resource<tensor<2xi64>>>
#   %45 = "tfl.var_handle"() <{container = "", shared_name = "seed_generator_2/seed_generator_state_1"}> : () -> tensor<!tf_type.resource<tensor<2xi64>>>
#   %46 = "tfl.read_variable"(%44) : (tensor<!tf_type.resource<tensor<2xi64>>>) -> tensor<2xi64>
#   %47 = "tfl.add"(%46, %20) <{fused_activation_function = "NONE"}> : (tensor<2xi64>, tensor<2xi64>) -> tensor<2xi64>
#   "tfl.assign_variable"(%44, %47) : (tensor<!tf_type.resource<tensor<2xi64>>>, tensor<2xi64>) -> ()
#   %48 = "tfl.read_variable"(%45) : (tensor<!tf_type.resource<tensor<2xi64>>>) -> tensor<2xi64>
#   %49 = "tfl.add"(%48, %20) <{fused_activation_function = "NONE"}> : (tensor<2xi64>, tensor<2xi64>) -> tensor<2xi64>
#   "tfl.assign_variable"(%45, %49) : (tensor<!tf_type.resource<tensor<2xi64>>>, tensor<2xi64>) -> ()
#   %50 = "tfl.read_variable"(%42) : (tensor<!tf_type.resource<tensor<2xi64>>>) -> tensor<2xi64>
#   %51 = "tfl.add"(%50, %20) <{fused_activation_function = "NONE"}> : (tensor<2xi64>, tensor<2xi64>) -> tensor<2xi64>
#   "tfl.assign_variable"(%42, %51) : (tensor<!tf_type.resource<tensor<2xi64>>>, tensor<2xi64>) -> ()
#   %52 = "tfl.read_variable"(%43) : (tensor<!tf_type.resource<tensor<2xi64>>>) -> tensor<2xi64>
#   %53 = "tfl.add"(%52, %20) <{fused_activation_function = "NONE"}> : (tensor<2xi64>, tensor<2xi64>) -> tensor<2xi64>
#   "tfl.assign_variable"(%43, %53) : (tensor<!tf_type.resource<tensor<2xi64>>>, tensor<2xi64>) -> ()
#   %54 = "tfl.cast"(%arg0) : (tensor<?x384x708xf32>) -> tensor<?x384x708xf16>
#   %55 = "tfl.cast"(%54) : (tensor<?x384x708xf16>) -> tensor<?x384x708xf32>
#   %56 = "tfl.not_equal"(%55, %12) : (tensor<?x384x708xf32>, tensor<f32>) -> tensor<?x384x708xi1>
#   %57 = "tfl.reduce_any"(%56, %13) <{keep_dims = false}> : (tensor<?x384x708xi1>, tensor<1xi32>) -> tensor<?x384xi1>
#   %58 = "tfl.logical_or"(%57, %57) : (tensor<?x384xi1>, tensor<?x384xi1>) -> tensor<?x384xi1>
#   %59 = "tfl.logical_or"(%58, %58) : (tensor<?x384xi1>, tensor<?x384xi1>) -> tensor<?x384xi1>
#   %60 = "tfl.cast"(%59) : (tensor<?x384xi1>) -> tensor<?x384xf16>
#   %61 = "tf.Sub"(%19, %60) {device = ""} : (tensor<f16>, tensor<?x384xf16>) -> tensor<?x384xf16>
#   %62 = "tf.Mul"(%61, %18) {device = ""} : (tensor<?x384xf16>, tensor<f16>) -> tensor<?x384xf16>
#   %63 = "tfl.expand_dims"(%60, %14) : (tensor<?x384xf16>, tensor<i32>) -> tensor<?x384x1xf16>
#   %64 = "tf.Sum"(%63, %10) <{keep_dims = false}> {device = ""} : (tensor<?x384x1xf16>, tensor<i32>) -> tensor<?x1xf16>
#   %65 = "tfl.cast"(%58) : (tensor<?x384xi1>) -> tensor<?x384xi32>
#   %66 = "tfl.sum"(%65, %10) <{keep_dims = false}> : (tensor<?x384xi32>, tensor<i32>) -> tensor<?xi32>
#   %67 = "tfl.cast"(%57) : (tensor<?x384xi1>) -> tensor<?x384xi32>
#   %68 = "tfl.sum"(%67, %10) <{keep_dims = false}> : (tensor<?x384xi32>, tensor<i32>) -> tensor<?xi32>
#   %69 = "tfl.reduce_any"(%56, %17) <{keep_dims = true}> : (tensor<?x384x708xi1>, tensor<i32>) -> tensor<?x384x1xi1>
#   %70 = "tfl.cast"(%69) : (tensor<?x384x1xi1>) -> tensor<?x384x1xf16>
#   %71 = "tf.Mul"(%54, %70) {device = ""} : (tensor<?x384x708xf16>, tensor<?x384x1xf16>) -> tensor<?x384x708xf16>
#   %72 = "tfl.expand_dims"(%71, %24) : (tensor<?x384x708xf16>, tensor<i32>) -> tensor<?x1x384x708xf16>
#   %73 = "tf.Conv2D"(%72, %41) <{data_format = "NHWC", dilations = [1, 1, 1, 1], explicit_paddings = [], padding = "SAME", strides = [1, 1, 1, 1], use_cudnn_on_gpu = true}> {device = ""} : (tensor<?x1x384x708xf16>, tensor<1x3x708x256xf16>) -> tensor<?x1x384x256xf16>
#   %74 = "tfl.reshape"(%73, %1) : (tensor<?x1x384x256xf16>, tensor<3xi32>) -> tensor<?x384x256xf16>
#   %75 = "tfl.cast"(%74) : (tensor<?x384x256xf16>) -> tensor<?x384x256xf32>
#   %76 = "tfl.mul"(%75, %39) <{fused_activation_function = "NONE"}> : (tensor<?x384x256xf32>, tensor<256xf32>) -> tensor<?x384x256xf32>
#   %77 = "tfl.add"(%76, %40) <{fused_activation_function = "NONE"}> : (tensor<?x384x256xf32>, tensor<256xf32>) -> tensor<?x384x256xf32>
#   %78 = "tfl.cast"(%77) : (tensor<?x384x256xf32>) -> tensor<?x384x256xf16>
#   %79 = "tf.Sigmoid"(%78) {device = ""} : (tensor<?x384x256xf16>) -> tensor<?x384x256xf16>
#   %80 = "tf.Mul"(%78, %79) {device = ""} : (tensor<?x384x256xf16>, tensor<?x384x256xf16>) -> tensor<?x384x256xf16>
#   %81 = "tf.ReverseSequence"(%80, %68) <{batch_dim = 0 : i64, seq_dim = 1 : i64}> {device = ""} : (tensor<?x384x256xf16>, tensor<?xi32>) -> tensor<?x384x256xf16>
#   %82 = "tfl.shape"(%80) : (tensor<?x384x256xf16>) -> tensor<3xi32>
#   %83 = "tfl.strided_slice"(%82, %15, %16, %16) <{begin_mask = 0 : i32, ellipsis_mask = 0 : i32, end_mask = 0 : i32, new_axis_mask = 0 : i32, offset = false, shrink_axis_mask = 1 : i32}> : (tensor<3xi32>, tensor<1xi32>, tensor<1xi32>, tensor<1xi32>) -> tensor<i32>
#   %84 = "tfl.pack"(%83, %11) <{axis = 0 : i32, values_count = 2 : i32}> : (tensor<i32>, tensor<i32>) -> tensor<2xi32>
#   %85 = "tfl.fill"(%84, %21) : (tensor<2xi32>, tensor<f16>) -> tensor<?x256xf16>
#   %86 = "tfl.expand_dims"(%85, %10) : (tensor<?x256xf16>, tensor<i32>) -> tensor<?x1x256xf16>
#   %87:5 = "tfl.custom_tf"(%81, %86, %21, %5, %68) ({
#   ^bb0(%arg16: tensor<?x384x256xf16>, %arg17: tensor<?x1x256xf16>, %arg18: tensor<f16>, %arg19: tensor<394752xf16>, %arg20: tensor<?xi32>):
#     %192:5 = "tf.CudnnRNNV3"(%arg16, %arg17, %arg18, %arg19, %arg20) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#     "tfl.yield"(%192#0, %192#1, %192#2, %192#3, %192#4) : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) -> ()
#   }) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#   %88 = "tf.ReverseSequence"(%87#0, %68) <{batch_dim = 0 : i64, seq_dim = 1 : i64}> {device = ""} : (tensor<?x384x256xf16>, tensor<?xi32>) -> tensor<?x384x256xf16>
#   %89 = "tf.ReverseV2"(%88, %16) {device = ""} : (tensor<?x384x256xf16>, tensor<1xi32>) -> tensor<?x384x256xf16>
#   %90 = "tf.ReverseV2"(%89, %16) {device = ""} : (tensor<?x384x256xf16>, tensor<1xi32>) -> tensor<?x384x256xf16>
#   %91:5 = "tfl.custom_tf"(%80, %86, %21, %26, %68) ({
#   ^bb0(%arg11: tensor<?x384x256xf16>, %arg12: tensor<?x1x256xf16>, %arg13: tensor<f16>, %arg14: tensor<394752xf16>, %arg15: tensor<?xi32>):
#     %191:5 = "tf.CudnnRNNV3"(%arg11, %arg12, %arg13, %arg14, %arg15) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#     "tfl.yield"(%191#0, %191#1, %191#2, %191#3, %191#4) : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) -> ()
#   }) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#   %92 = "tf.ConcatV2"(%91#0, %90, %17) {device = ""} : (tensor<?x384x256xf16>, tensor<?x384x256xf16>, tensor<i32>) -> tensor<?x384x512xf16>
#   %93 = "tfl.cast"(%92) : (tensor<?x384x512xf16>) -> tensor<?x384x512xf32>
#   %94 = "tfl.mean"(%93, %13) <{keep_dims = true}> : (tensor<?x384x512xf32>, tensor<1xi32>) -> tensor<?x384x1xf32>
#   %95 = "tfl.neg"(%94) : (tensor<?x384x1xf32>) -> tensor<?x384x1xf32>
#   %96 = "tfl.squared_difference"(%93, %94) : (tensor<?x384x512xf32>, tensor<?x384x1xf32>) -> tensor<?x384x512xf32>
#   %97 = "tfl.mean"(%96, %13) <{keep_dims = true}> : (tensor<?x384x512xf32>, tensor<1xi32>) -> tensor<?x384x1xf32>
#   %98 = "tfl.add"(%97, %23) <{fused_activation_function = "NONE"}> : (tensor<?x384x1xf32>, tensor<f32>) -> tensor<?x384x1xf32>
#   %99 = "tfl.rsqrt"(%98) : (tensor<?x384x1xf32>) -> tensor<?x384x1xf32>
#   %100 = "tfl.mul"(%99, %32) <{fused_activation_function = "NONE"}> : (tensor<?x384x1xf32>, tensor<1x1x512xf32>) -> tensor<?x384x512xf32>
#   %101 = "tfl.mul"(%95, %100) <{fused_activation_function = "NONE"}> : (tensor<?x384x1xf32>, tensor<?x384x512xf32>) -> tensor<?x384x512xf32>
#   %102 = "tfl.add"(%101, %31) <{fused_activation_function = "NONE"}> : (tensor<?x384x512xf32>, tensor<1x1x512xf32>) -> tensor<?x384x512xf32>
#   %103 = "tfl.mul"(%93, %100) <{fused_activation_function = "NONE"}> : (tensor<?x384x512xf32>, tensor<?x384x512xf32>) -> tensor<?x384x512xf32>
#   %104 = "tfl.add"(%103, %102) <{fused_activation_function = "NONE"}> : (tensor<?x384x512xf32>, tensor<?x384x512xf32>) -> tensor<?x384x512xf32>
#   %105 = "tfl.cast"(%104) : (tensor<?x384x512xf32>) -> tensor<?x384x512xf16>
#   %106 = "tf.BatchMatMulV2"(%80, %37) <{adj_x = false, adj_y = false, grad_x = false, grad_y = false}> {device = ""} : (tensor<?x384x256xf16>, tensor<256x512xf16>) -> tensor<?x384x512xf16>
#   %107 = "tf.AddV2"(%105, %106) {device = ""} : (tensor<?x384x512xf16>, tensor<?x384x512xf16>) -> tensor<?x384x512xf16>
#   %108 = "tf.ReverseSequence"(%107, %66) <{batch_dim = 0 : i64, seq_dim = 1 : i64}> {device = ""} : (tensor<?x384x512xf16>, tensor<?xi32>) -> tensor<?x384x512xf16>
#   %109 = "tfl.shape"(%107) : (tensor<?x384x512xf16>) -> tensor<3xi32>
#   %110 = "tfl.strided_slice"(%109, %15, %16, %16) <{begin_mask = 0 : i32, ellipsis_mask = 0 : i32, end_mask = 0 : i32, new_axis_mask = 0 : i32, offset = false, shrink_axis_mask = 1 : i32}> : (tensor<3xi32>, tensor<1xi32>, tensor<1xi32>, tensor<1xi32>) -> tensor<i32>
#   %111 = "tfl.pack"(%110, %22) <{axis = 0 : i32, values_count = 2 : i32}> : (tensor<i32>, tensor<i32>) -> tensor<2xi32>
#   %112 = "tfl.fill"(%111, %21) : (tensor<2xi32>, tensor<f16>) -> tensor<?x128xf16>
#   %113 = "tfl.expand_dims"(%112, %10) : (tensor<?x128xf16>, tensor<i32>) -> tensor<?x1x128xf16>
#   %114:5 = "tfl.custom_tf"(%108, %113, %21, %27, %66) ({
#   ^bb0(%arg6: tensor<?x384x512xf16>, %arg7: tensor<?x1x128xf16>, %arg8: tensor<f16>, %arg9: tensor<246528xf16>, %arg10: tensor<?xi32>):
#     %190:5 = "tf.CudnnRNNV3"(%arg6, %arg7, %arg8, %arg9, %arg10) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#     "tfl.yield"(%190#0, %190#1, %190#2, %190#3, %190#4) : (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) -> ()
#   }) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#   %115 = "tf.ReverseSequence"(%114#0, %66) <{batch_dim = 0 : i64, seq_dim = 1 : i64}> {device = ""} : (tensor<?x384x128xf16>, tensor<?xi32>) -> tensor<?x384x128xf16>
#   %116 = "tf.ReverseV2"(%115, %16) {device = ""} : (tensor<?x384x128xf16>, tensor<1xi32>) -> tensor<?x384x128xf16>
#   %117 = "tf.ReverseV2"(%116, %16) {device = ""} : (tensor<?x384x128xf16>, tensor<1xi32>) -> tensor<?x384x128xf16>
#   %118:5 = "tfl.custom_tf"(%107, %113, %21, %28, %66) ({
#   ^bb0(%arg1: tensor<?x384x512xf16>, %arg2: tensor<?x1x128xf16>, %arg3: tensor<f16>, %arg4: tensor<246528xf16>, %arg5: tensor<?xi32>):
#     %189:5 = "tf.CudnnRNNV3"(%arg1, %arg2, %arg3, %arg4, %arg5) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#     "tfl.yield"(%189#0, %189#1, %189#2, %189#3, %189#4) : (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) -> ()
#   }) {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false} : (tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>)
#   %119 = "tf.ConcatV2"(%118#0, %117, %17) {device = ""} : (tensor<?x384x128xf16>, tensor<?x384x128xf16>, tensor<i32>) -> tensor<?x384x256xf16>
#   %120 = "tfl.cast"(%119) : (tensor<?x384x256xf16>) -> tensor<?x384x256xf32>
#   %121 = "tfl.mean"(%120, %13) <{keep_dims = true}> : (tensor<?x384x256xf32>, tensor<1xi32>) -> tensor<?x384x1xf32>
#   %122 = "tfl.neg"(%121) : (tensor<?x384x1xf32>) -> tensor<?x384x1xf32>
#   %123 = "tfl.squared_difference"(%120, %121) : (tensor<?x384x256xf32>, tensor<?x384x1xf32>) -> tensor<?x384x256xf32>
#   %124 = "tfl.mean"(%123, %13) <{keep_dims = true}> : (tensor<?x384x256xf32>, tensor<1xi32>) -> tensor<?x384x1xf32>
#   %125 = "tfl.add"(%124, %23) <{fused_activation_function = "NONE"}> : (tensor<?x384x1xf32>, tensor<f32>) -> tensor<?x384x1xf32>
#   %126 = "tfl.rsqrt"(%125) : (tensor<?x384x1xf32>) -> tensor<?x384x1xf32>
#   %127 = "tfl.mul"(%126, %34) <{fused_activation_function = "NONE"}> : (tensor<?x384x1xf32>, tensor<1x1x256xf32>) -> tensor<?x384x256xf32>
#   %128 = "tfl.mul"(%122, %127) <{fused_activation_function = "NONE"}> : (tensor<?x384x1xf32>, tensor<?x384x256xf32>) -> tensor<?x384x256xf32>
#   %129 = "tfl.add"(%128, %33) <{fused_activation_function = "NONE"}> : (tensor<?x384x256xf32>, tensor<1x1x256xf32>) -> tensor<?x384x256xf32>
#   %130 = "tfl.mul"(%120, %127) <{fused_activation_function = "NONE"}> : (tensor<?x384x256xf32>, tensor<?x384x256xf32>) -> tensor<?x384x256xf32>
#   %131 = "tfl.add"(%130, %129) <{fused_activation_function = "NONE"}> : (tensor<?x384x256xf32>, tensor<?x384x256xf32>) -> tensor<?x384x256xf32>
#   %132 = "tfl.cast"(%131) : (tensor<?x384x256xf32>) -> tensor<?x384x256xf16>
#   %133 = "tf.BatchMatMulV2"(%107, %38) <{adj_x = false, adj_y = false, grad_x = false, grad_y = false}> {device = ""} : (tensor<?x384x512xf16>, tensor<512x256xf16>) -> tensor<?x384x256xf16>
#   %134 = "tf.AddV2"(%132, %133) {device = ""} : (tensor<?x384x256xf16>, tensor<?x384x256xf16>) -> tensor<?x384x256xf16>
#   %135 = "tfl.shape"(%134) : (tensor<?x384x256xf16>) -> tensor<3xi32>
#   %136 = "tf.BatchMatMulV2"(%134, %8) <{adj_x = false, adj_y = false, grad_x = false, grad_y = false}> {device = ""} : (tensor<?x384x256xf16>, tensor<256x64xf16>) -> tensor<?x384x64xf16>
#   %137 = "tf.BiasAdd"(%136, %9) <{data_format = "NHWC"}> {device = ""} : (tensor<?x384x64xf16>, tensor<64xf16>) -> tensor<?x384x64xf16>
#   %138 = "tf.Tanh"(%137) {device = ""} : (tensor<?x384x64xf16>) -> tensor<?x384x64xf16>
#   %139 = "tf.BatchMatMulV2"(%138, %6) <{adj_x = false, adj_y = false, grad_x = false, grad_y = false}> {device = ""} : (tensor<?x384x64xf16>, tensor<64x1xf16>) -> tensor<?x384x1xf16>
#   %140 = "tf.AddV2"(%139, %7) {device = ""} : (tensor<?x384x1xf16>, tensor<1xf16>) -> tensor<?x384x1xf16>
#   %141 = "tfl.reshape"(%140, %0) : (tensor<?x384x1xf16>, tensor<2xi32>) -> tensor<?x384xf16>
#   %142 = "tf.AddV2"(%141, %62) {device = ""} : (tensor<?x384xf16>, tensor<?x384xf16>) -> tensor<?x384xf16>
#   %143 = "tf.Softmax"(%142) {device = ""} : (tensor<?x384xf16>) -> tensor<?x384xf16>
#   %144 = "tf.Mul"(%143, %60) {device = ""} : (tensor<?x384xf16>, tensor<?x384xf16>) -> tensor<?x384xf16>
#   %145 = "tfl.expand_dims"(%144, %17) : (tensor<?x384xf16>, tensor<i32>) -> tensor<?x384x1xf16>
#   %146 = "tfl.shape"(%145) : (tensor<?x384x1xf16>) -> tensor<3xi32>
#   %147 = "tf.Mul"(%134, %63) {device = ""} : (tensor<?x384x256xf16>, tensor<?x384x1xf16>) -> tensor<?x384x256xf16>
#   %148 = "tf.Sum"(%147, %10) <{keep_dims = false}> {device = ""} : (tensor<?x384x256xf16>, tensor<i32>) -> tensor<?x256xf16>
#   %149 = "tf.RealDiv"(%148, %64) {device = ""} : (tensor<?x256xf16>, tensor<?x1xf16>) -> tensor<?x256xf16>
#   %150 = "tf.Max"(%134, %10) <{keep_dims = false}> {device = ""} : (tensor<?x384x256xf16>, tensor<i32>) -> tensor<?x256xf16>
#   %151 = "tfl.reshape"(%69, %0) : (tensor<?x384x1xi1>, tensor<2xi32>) -> tensor<?x384xi1>
#   %152 = "tfl.logical_or"(%151, %151) : (tensor<?x384xi1>, tensor<?x384xi1>) -> tensor<?x384xi1>
#   %153 = "tfl.logical_or"(%152, %152) : (tensor<?x384xi1>, tensor<?x384xi1>) -> tensor<?x384xi1>
#   %154 = "tfl.expand_dims"(%153, %14) : (tensor<?x384xi1>, tensor<i32>) -> tensor<?x384x1xi1>
#   %155 = "tfl.broadcast_to"(%154, %135) : (tensor<?x384x1xi1>, tensor<3xi32>) -> tensor<?x384x256xi1>
#   %156 = "tf.SelectV2"(%155, %134, %19) {device = ""} : (tensor<?x384x256xi1>, tensor<?x384x256xf16>, tensor<f16>) -> tensor<?x384x256xf16>
#   %157 = "tfl.broadcast_to"(%154, %146) : (tensor<?x384x1xi1>, tensor<3xi32>) -> tensor<?x384x1xi1>
#   %158 = "tfl.logical_or"(%155, %157) : (tensor<?x384x256xi1>, tensor<?x384x1xi1>) -> tensor<?x384x256xi1>
#   %159 = "tf.SelectV2"(%157, %145, %19) {device = ""} : (tensor<?x384x1xi1>, tensor<?x384x1xf16>, tensor<f16>) -> tensor<?x384x1xf16>
#   %160 = "tf.Mul"(%156, %159) {device = ""} : (tensor<?x384x256xf16>, tensor<?x384x1xf16>) -> tensor<?x384x256xf16>
#   %161 = "tf.SelectV2"(%158, %160, %21) {device = ""} : (tensor<?x384x256xi1>, tensor<?x384x256xf16>, tensor<f16>) -> tensor<?x384x256xf16>
#   %162 = "tf.Sum"(%161, %10) <{keep_dims = false}> {device = ""} : (tensor<?x384x256xf16>, tensor<i32>) -> tensor<?x256xf16>
#   %163 = "tf.ConcatV2"(%162, %149, %150, %17) {device = ""} : (tensor<?x256xf16>, tensor<?x256xf16>, tensor<?x256xf16>, tensor<i32>) -> tensor<?x768xf16>
#   %164 = "tf.MatMul"(%163, %4) <{grad_a = false, grad_b = false, transpose_a = false, transpose_b = true}> : (tensor<?x768xf16>, tensor<256x768xf16>) -> tensor<?x256xf16>
#   %165 = "tfl.cast"(%164) : (tensor<?x256xf16>) -> tensor<?x256xf32>
#   %166 = "tfl.mean"(%165, %13) <{keep_dims = true}> : (tensor<?x256xf32>, tensor<1xi32>) -> tensor<?x1xf32>
#   %167 = "tfl.neg"(%166) : (tensor<?x1xf32>) -> tensor<?x1xf32>
#   %168 = "tfl.squared_difference"(%165, %166) : (tensor<?x256xf32>, tensor<?x1xf32>) -> tensor<?x256xf32>
#   %169 = "tfl.mean"(%168, %13) <{keep_dims = true}> : (tensor<?x256xf32>, tensor<1xi32>) -> tensor<?x1xf32>
#   %170 = "tfl.add"(%169, %23) <{fused_activation_function = "NONE"}> : (tensor<?x1xf32>, tensor<f32>) -> tensor<?x1xf32>
#   %171 = "tfl.rsqrt"(%170) : (tensor<?x1xf32>) -> tensor<?x1xf32>
#   %172 = "tfl.mul"(%171, %36) <{fused_activation_function = "NONE"}> : (tensor<?x1xf32>, tensor<1x256xf32>) -> tensor<?x256xf32>
#   %173 = "tfl.mul"(%167, %172) <{fused_activation_function = "NONE"}> : (tensor<?x1xf32>, tensor<?x256xf32>) -> tensor<?x256xf32>
#   %174 = "tfl.add"(%173, %35) <{fused_activation_function = "NONE"}> : (tensor<?x256xf32>, tensor<1x256xf32>) -> tensor<?x256xf32>
#   %175 = "tfl.mul"(%165, %172) <{fused_activation_function = "NONE"}> : (tensor<?x256xf32>, tensor<?x256xf32>) -> tensor<?x256xf32>
#   %176 = "tfl.add"(%175, %174) <{fused_activation_function = "NONE"}> : (tensor<?x256xf32>, tensor<?x256xf32>) -> tensor<?x256xf32>
#   %177 = "tfl.cast"(%176) : (tensor<?x256xf32>) -> tensor<?x256xf16>
#   %178 = "tf.Sigmoid"(%177) {device = ""} : (tensor<?x256xf16>) -> tensor<?x256xf16>
#   %179 = "tf.Mul"(%177, %178) {device = ""} : (tensor<?x256xf16>, tensor<?x256xf16>) -> tensor<?x256xf16>
#   %180 = "tf.MatMul"(%179, %3) <{grad_a = false, grad_b = false, transpose_a = false, transpose_b = true}> : (tensor<?x256xf16>, tensor<256x256xf16>) -> tensor<?x256xf16>
#   %181 = "tf.Sigmoid"(%180) {device = ""} : (tensor<?x256xf16>) -> tensor<?x256xf16>
#   %182 = "tf.Mul"(%180, %181) {device = ""} : (tensor<?x256xf16>, tensor<?x256xf16>) -> tensor<?x256xf16>
#   %183 = "tfl.cast"(%182) : (tensor<?x256xf16>) -> tensor<?x256xf32>
#   %184 = "tfl.mul"(%183, %29) <{fused_activation_function = "NONE"}> : (tensor<?x256xf32>, tensor<256xf32>) -> tensor<?x256xf32>
#   %185 = "tfl.add"(%184, %30) <{fused_activation_function = "NONE"}> : (tensor<?x256xf32>, tensor<256xf32>) -> tensor<?x256xf32>
#   %186 = "tfl.cast"(%185) : (tensor<?x256xf32>) -> tensor<?x256xf16>
#   %187 = "tfl.cast"(%186) : (tensor<?x256xf16>) -> tensor<?x256xf32>
#   %188 = "tfl.fully_connected"(%187, %2, %25) <{fused_activation_function = "NONE", keep_num_dims = false, weights_format = "DEFAULT"}> : (tensor<?x256xf32>, tensor<250x256xf32>, tensor<250xf32>) -> tensor<?x250xf32>
#   "func.return"(%188) : (tensor<?x250xf32>) -> ()
# }) {tf.entry_function = {control_outputs = "", inputs = "serving_default_input_features:0", outputs = "StatefulPartitionedCall_1:0"}, tf_saved_model.exported_names = ["serving_default"]} : () -> ()
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1776080125.895485      22 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1776080125.895571      22 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# I0000 00:00:1776080125.933925      22 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/backward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_1_1/forward_gru_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/backward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# loc(callsite(callsite(fused["CudnnRNNV3:", "BiGRU_1/bigru_2_1/forward_gru_1_1/CudnnRNNV3@__inference___call___4458"] at fused["StatefulPartitionedCall:", "StatefulPartitionedCall@__inference_signature_wrapper___call___4633"]) at fused["StatefulPartitionedCall:", "StatefulPartitionedCall_1"])): error: 'tf.CudnnRNNV3' op is neither a custom op nor a flex op
# error: failed while converting: 'main':
# Some ops in the model are custom ops, See instructions to implement custom ops: https://www.tensorflow.org/lite/guide/ops_custom
# Custom ops: CudnnRNNV3
# Details:
# 	tf.CudnnRNNV3(tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<394752xf16>, tensor<?xi32>) -> (tensor<?x384x256xf16>, tensor<?x1x256xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) : {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# 	tf.CudnnRNNV3(tensor<?x384x512xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<246528xf16>, tensor<?xi32>) -> (tensor<?x384x128xf16>, tensor<?x1x128xf16>, tensor<f16>, tensor<*xf16>, tensor<*xi8>) : {T = f16, device = "", direction = "unidirectional", dropout = 0.000000e+00 : f32, input_mode = "linear_input", is_training = true, num_proj = 0 : i64, rnn_mode = "gru", seed = 0 : i64, seed2 = 0 : i64, time_major = false}
# Export complete: /kaggle/working/final_model_BiGRU.zip  (27.2 MB)
# Load:  model = tf.saved_model.load('/kaggle/working/final_model_BiGRU/final_model_BiGRU')

# %%
# -- Quick sanity check -------------------------------------------------------
import numpy as np

_sm          = tf.saved_model.load(_sm_path)
_channels    = _sm.serve.input_signature[0].shape[-1]
_dummy       = np.random.randn(1, CFG.MAX_LEN, _channels).astype("float32")
_out         = _sm.serve(tf.constant(_dummy))

assert _out.shape == (1, CFG.NUM_CLASSES), f"Unexpected output shape: {_out.shape}"

_pred        = int(tf.argmax(_out, axis=-1).numpy()[0])
_prob        = float(tf.nn.softmax(_out)[0][_pred])

print(f"SavedModel OK  |  output: {_out.shape}  |  top-1: {label_to_sign.get(_pred, _pred)} ({_prob:.4f})")
# Out:
# I0000 00:00:1776080129.760593      68 cuda_dnn.cc:529] Loaded cuDNN version 91002
# SavedModel OK  |  output: (1, 250)  |  top-1: cereal (0.0265)
